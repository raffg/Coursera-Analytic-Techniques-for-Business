# %% [markdown]
# # Watershed Properties Data Extraction with SQL

# %% [markdown]
# Watershed's intern put together a couple of sources of information that will be useful for your project. These three types of information are contained in the capstone database:
# 1. the current monthly rent Watershed charges for all of their client’s 244 properties, as well as the property type and geographic location of those properties.
# 2. some general information about examples of short-term rental properties.  This information can be used to get a sense of what kind of nightly rental price Watershed’s client’s properties *could* be listed for, if they were converted to short-term rentals.
# 3. records about when those short-term rental properties were rented out, so that you can calculate their occupancy rates.

# %% [markdown]
# Your job is to determine how the database is organized so that you can retrieve all of the available information about Watershed’s client’s 244 properties, as well as the corresponding short-term rental information for comparable properties in the same location and of the same type.
# 1. Start by determining what tables the database contains, and what fields are included in each table.
# 2. Then, we recommend that you make at least a rough relational schema of how the database is organized, so that you know what fields you can use to join tables.
# 3. Next, make a list of the columns of data you want to retrieve in your final output.
# 4. Finally, write your query to retrieve the desired data from the database.

# %% [markdown]
# ### Load and connect to the database

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@mysqlserver/capstone 
# %sql USE capstone
# Out:
# 0 rows affected.
# []

# %% [markdown]
# ### Queries

# %% [markdown]
# #### Explore the database in order to build a relational schema

# %%
# %sql SHOW tables
# Out:
# 6 rows affected.
# [('location',),
#  ('property_type',),
#  ('st_property_info',),
#  ('st_rental_dates',),
#  ('st_rental_prices',),
#  ('watershed_property_info',)]

# %%
# %sql SHOW columns FROM location
# Out:
# 4 rows affected.
# [('location_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('city', 'varchar(255)', 'YES', '', None, ''),
#  ('state', 'varchar(255)', 'YES', '', None, ''),
#  ('zipcode', 'int(5)', 'YES', '', None, '')]

# %%
# %sql SHOW columns FROM property_type
# Out:
# 5 rows affected.
# [('property_type_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('apt_house', 'varchar(255)', 'YES', '', None, ''),
#  ('num_bedrooms', 'varchar(255)', 'YES', '', None, ''),
#  ('kitchen', 'varchar(255)', 'YES', '', None, ''),
#  ('shared', 'varchar(255)', 'YES', '', None, '')]

# %%
# %sql SHOW columns FROM st_property_info
# Out:
# 3 rows affected.
# [('st_property_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(255)', 'YES', '', None, ''),
#  ('property_type', 'varchar(255)', 'YES', '', None, '')]

# %%
# %sql SHOW columns FROM st_rental_dates
# Out:
# 2 rows affected.
# [('rental_date', 'date', 'NO', 'PRI', None, ''),
#  ('st_property', 'varchar(255)', 'NO', 'PRI', None, '')]

# %%
# %sql SHOW columns FROM st_rental_prices
# Out:
# 5 rows affected.
# [('location', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('property_type', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('percentile_10th_price', 'int(11)', 'YES', '', None, ''),
#  ('percentile_90th_price', 'int(11)', 'YES', '', None, ''),
#  ('sample_nightly_rent_price', 'int(11)', 'YES', '', None, '')]

# %%
# %sql SHOW columns FROM watershed_property_info
# Out:
# 4 rows affected.
# [('ws_property_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(255)', 'YES', '', None, ''),
#  ('property_type', 'varchar(255)', 'YES', '', None, ''),
#  ('current_monthly_rent', 'int(11)', 'NO', '', None, '')]

# %% [markdown]
# #### How many properties are in the location table?

# %%
# %%sql
# SELECT location_id
# FROM location
# Out:
# 18218 rows affected.
# [('L1',),
#  ('L10',),
#  ('L100',),
#  ('L1000',),
#  ('L10000',),
#  ('L10001',),
#  ('L10002',),
#  ('L10003',),
#  ('L10004',),
#  ('L10005',),
#  ('L10006',),
#  ('L10007',),
#  ('L10008',),
#  ('L10009',),
#  ('L1001',),
#  ('L10010',),
#  ('L10011',),
#  ('L10012',),
#  ('L10013',),
#  ('L10014',),
#  ('L10015',),
#  ('L10016',),
#  ('L10017',),
#  ('L10018',),
#  ('L10019',),
#  ('L1002',),
#  ('L10020',),
#  ('L10021',),
#  ('L10022',),
#  ('L10023',),
#  ('L10024',),
#  ('L10025',),
#  ('L10026',),
#  ('L10027',),
#  ('L10028',),
#  ('L10029',),
#  ('L1003',),
#  ('L10030',),
#  ('L10031',),
#  ('L10032',),
#  ('L10033',),
#  ('L10034',),
#  ('L10035',),
#  ('L10036',),
#  ('L10037',),
#  ('L10038',),
#  ('L10039',),
#  ('L1004',),
#  ('L10040',),
#  ('L10041',),
#  ('L10042',),
#  ('L10043',),
#  ('L10044',),
#  ('L10045',),
#  ('L10046',),
#  ('L10047',),
#  ('L10048',),
#  ('L10049',),
#  ('L1005',),
#  ('L10050',),
#  ('L10051',),
#  ('L10052',),
#  ('L10053',),
#  ('L10054',),
#  ('L10055',),
#  ('L10056',),
#  ('L10057',),
#  ('L10058',),
#  ('L10059',),
#  ('L1006',),
#  ('L10060',),
#  ('L10061',),
#  ('L10062',),
#  ('L10063',),
#  ('L10064',),
#  ('L10065',),
#  ('L10066',),
#  ('L10067',),
#  ('L10068',),
#  ('L10069',),
#  ('L1007',),
#  ('L10070',),
#  ('L10071',),
#  ('L10072',),
#  ('L10073',),
#  ('L10074',),
#  ('L10075',),
#  ('L10076',),
#  ('L10077',),
#  ('L10078',),
#  ('L10079',),
#  ('L1008',),
#  ('L10080',),
#  ('L10081',),
#  ('L10082',),
#  ('L10083',),
#  ('L10084',),
#  ('L10085',),
#  ('L10086',),
#  ('L10087',),
#  ('L10088',),
#  ('L10089',),
#  ('L1009',),
#  ('L10090',),
#  ('L10091',),
#  ('L10092',),
#  ('L10093',),
#  ('L10094',),
#  ('L10095',),
#  ('L10096',),
#  ('L10097',),
#  ('L10098',),
#  ('L10099',),
#  ('L101',),
#  ('L1010',),
#  ('L10100',),
#  ('L10101',),
#  ('L10102',),
#  ('L10103',),
#  ('L10104',),
#  ('L10105',),
#  ('L10106',),
#  ('L10107',),
#  ('L10108',),
#  ('L10109',),
#  ('L1011',),
#  ('L10110',),
#  ('L10111',),
#  ('L10112',),
#  ('L10113',),
#  ('L10114',),
#  ('L10115',),
#  ('L10116',),
#  ('L10117',),
#  ('L10118',),
#  ('L10119',),
#  ('L1012',),
#  ('L10120',),
#  ('L10121',),
#  ('L10122',),
#  ('L10123',),
#  ('L10124',),
#  ('L10125',),
#  ('L10126',),
#  ('L10127',),
#  ('L10128',),
#  ('L10129',),
#  ('L1013',),
#  ('L10130',),
#  ('L10131',),
#  ('L10132',),
#  ('L10133',),
#  ('L10134',),
#  ('L10135',),
#  ('L10136',),
#  ('L10137',),
#  ('L10138',),
#  ('L10139',),
#  ('L1014',),
#  ('L10140',),
#  ('L10141',),
#  ('L10142',),
#  ('L10143',),
#  ('L10144',),
#  ('L10145',),
#  ('L10146',),
#  ('L10147',),
#  ('L10148',),
#  ('L10149',),
#  ('L1015',),
#  ('L10150',),
#  ('L10151',),
#  ('L10152',),
#  ('L10153',),
#  ('L10154',),
#  ('L10155',),
#  ('L10156',),
#  ('L10157',),
#  ('L10158',),
#  ('L10159',),
#  ('L1016',),
#  ('L10160',),
#  ('L10161',),
#  ('L10162',),
#  ('L10163',),
#  ('L10164',),
#  ('L10165',),
#  ('L10166',),
#  ('L10167',),
#  ('L10168',),
#  ('L10169',),
#  ('L1017',),
#  ('L10170',),
#  ('L10171',),
#  ('L10172',),
#  ('L10173',),
#  ('L10174',),
#  ('L10175',),
#  ('L10176',),
#  ('L10177',),
#  ('L10178',),
#  ('L10179',),
#  ('L1018',),
#  ('L10180',),
#  ('L10181',),
#  ('L10182',),
#  ('L10183',),
#  ('L10184',),
#  ('L10185',),
#  ('L10186',),
#  ('L10187',),
#  ('L10188',),
#  ('L10189',),
#  ('L1019',),
#  ('L10190',),
#  ('L10191',),
#  ('L10192',),
#  ('L10193',),
#  ('L10194',),
#  ('L10195',),
#  ('L10196',),
#  ('L10197',),
#  ('L10198',),
#  ('L10199',),
#  ('L102',),
#  ('L1020',),
#  ('L10200',),
#  ('L10201',),
#  ('L10202',),
#  ('L10203',),
#  ('L10204',),
#  ('L10205',),
#  ('L10206',),
#  ('L10207',),
#  ('L10208',),
#  ('L10209',),
#  ('L1021',),
#  ('L10210',),
#  ('L10211',),
#  ('L10212',),
#  ('L10213',),
#  ('L10214',),
#  ('L10215',),
#  ('L10216',),
#  ('L10217',),
#  ('L10218',),
#  ('L10219',),
#  ('L1022',),
#  ('L10220',),
#  ('L10221',),
#  ('L10222',),
#  ('L10223',),
#  ('L10224',),
#  ('L10225',),
#  ('L10226',),
#  ('L10227',),
#  ('L10228',),
#  ('L10229',),
#  ('L1023',),
#  ('L10230',),
#  ('L10231',),
#  ('L10232',),
#  ('L10233',),
#  ('L10234',),
#  ('L10235',),
#  ('L10236',),
#  ('L10237',),
#  ('L10238',),
#  ('L10239',),
#  ('L1024',),
#  ('L10240',),
#  ('L10241',),
#  ('L10242',),
#  ('L10243',),
#  ('L10244',),
#  ('L10245',),
#  ('L10246',),
#  ('L10247',),
#  ('L10248',),
#  ('L10249',),
#  ('L1025',),
#  ('L10250',),
#  ('L10251',),
#  ('L10252',),
#  ('L10253',),
#  ('L10254',),
#  ('L10255',),
#  ('L10256',),
#  ('L10257',),
#  ('L10258',),
#  ('L10259',),
#  ('L1026',),
#  ('L10260',),
#  ('L10261',),
#  ('L10262',),
#  ('L10263',),
#  ('L10264',),
#  ('L10265',),
#  ('L10266',),
#  ('L10267',),
#  ('L10268',),
#  ('L10269',),
#  ('L1027',),
#  ('L10270',),
#  ('L10271',),
#  ('L10272',),
#  ('L10273',),
#  ('L10274',),
#  ('L10275',),
#  ('L10276',),
#  ('L10277',),
#  ('L10278',),
#  ('L10279',),
#  ('L1028',),
#  ('L10280',),
#  ('L10281',),
#  ('L10282',),
#  ('L10283',),
#  ('L10284',),
#  ('L10285',),
#  ('L10286',),
#  ('L10287',),
#  ('L10288',),
#  ('L10289',),
#  ('L1029',),
#  ('L10290',),
#  ('L10291',),
#  ('L10292',),
#  ('L10293',),
#  ('L10294',),
#  ('L10295',),
#  ('L10296',),
#  ('L10297',),
#  ('L10298',),
#  ('L10299',),
#  ('L103',),
#  ('L1030',),
#  ('L10300',),
#  ('L10301',),
#  ('L10302',),
#  ('L10303',),
#  ('L10304',),
#  ('L10305',),
#  ('L10306',),
#  ('L10307',),
#  ('L10308',),
#  ('L10309',),
#  ('L1031',),
#  ('L10310',),
#  ('L10311',),
#  ('L10312',),
#  ('L10313',),
#  ('L10314',),
#  ('L10315',),
#  ('L10316',),
#  ('L10317',),
#  ('L10318',),
#  ('L10319',),
#  ('L1032',),
#  ('L10320',),
#  ('L10321',),
#  ('L10322',),
#  ('L10323',),
#  ('L10324',),
#  ('L10325',),
#  ('L10326',),
#  ('L10327',),
#  ('L10328',),
#  ('L10329',),
#  ('L1033',),
#  ('L10330',),
#  ('L10331',),
#  ('L10332',),
#  ('L10333',),
#  ('L10334',),
#  ('L10335',),
#  ('L10336',),
#  ('L10337',),
#  ('L10338',),
#  ('L10339',),
#  ('L1034',),
#  ('L10340',),
#  ('L10341',),
#  ('L10342',),
#  ('L10343',),
#  ('L10344',),
#  ('L10345',),
#  ('L10346',),
#  ('L10347',),
#  ('L10348',),
#  ('L10349',),
#  ('L1035',),
#  ('L10350',),
#  ('L10351',),
#  ('L10352',),
#  ('L10353',),
#  ('L10354',),
#  ('L10355',),
#  ('L10356',),
#  ('L10357',),
#  ('L10358',),
#  ('L10359',),
#  ('L1036',),
#  ('L10360',),
#  ('L10361',),
#  ('L10362',),
#  ('L10363',),
#  ('L10364',),
#  ('L10365',),
#  ('L10366',),
#  ('L10367',),
#  ('L10368',),
#  ('L10369',),
#  ('L1037',),
#  ('L10370',),
#  ('L10371',),
#  ('L10372',),
#  ('L10373',),
#  ('L10374',),
#  ('L10375',),
#  ('L10376',),
#  ('L10377',),
#  ('L10378',),
#  ('L10379',),
#  ('L1038',),
#  ('L10380',),
#  ('L10381',),
#  ('L10382',),
#  ('L10383',),
#  ('L10384',),
#  ('L10385',),
#  ('L10386',),
#  ('L10387',),
#  ('L10388',),
#  ('L10389',),
#  ('L1039',),
#  ('L10390',),
#  ('L10391',),
#  ('L10392',),
#  ('L10393',),
#  ('L10394',),
#  ('L10395',),
#  ('L10396',),
#  ('L10397',),
#  ('L10398',),
#  ('L10399',),
#  ('L104',),
#  ('L1040',),
#  ('L10400',),
#  ('L10401',),
#  ('L10402',),
#  ('L10403',),
#  ('L10404',),
#  ('L10405',),
#  ('L10406',),
#  ('L10407',),
#  ('L10408',),
#  ('L10409',),
#  ('L1041',),
#  ('L10410',),
#  ('L10411',),
#  ('L10412',),
#  ('L10413',),
#  ('L10414',),
#  ('L10415',),
#  ('L10416',),
#  ('L10417',),
#  ('L10418',),
#  ('L10419',),
#  ('L1042',),
#  ('L10420',),
#  ('L10421',),
#  ('L10422',),
#  ('L10423',),
#  ('L10424',),
#  ('L10425',),
#  ('L10426',),
#  ('L10427',),
#  ('L10428',),
#  ('L10429',),
#  ('L1043',),
#  ('L10430',),
#  ('L10431',),
#  ('L10432',),
#  ('L10433',),
#  ('L10434',),
#  ('L10435',),
#  ('L10436',),
#  ('L10437',),
#  ('L10438',),
#  ('L10439',),
#  ('L1044',),
#  ('L10440',),
#  ('L10441',),
#  ('L10442',),
#  ('L10443',),
#  ('L10444',),
#  ('L10445',),
#  ('L10446',),
#  ('L10447',),
#  ('L10448',),
#  ('L10449',),
#  ('L1045',),
#  ('L10450',),
#  ('L10451',),
#  ('L10452',),
#  ('L10453',),
#  ('L10454',),
#  ('L10455',),
#  ('L10456',),
#  ('L10457',),
#  ('L10458',),
#  ('L10459',),
#  ('L1046',),
#  ('L10460',),
#  ('L10461',),
#  ('L10462',),
#  ('L10463',),
#  ('L10464',),
#  ('L10465',),
#  ('L10466',),
#  ('L10467',),
#  ('L10468',),
#  ('L10469',),
#  ('L1047',),
#  ('L10470',),
#  ('L10471',),
#  ('L10472',),
#  ('L10473',),
#  ('L10474',),
#  ('L10475',),
#  ('L10476',),
#  ('L10477',),
#  ('L10478',),
#  ('L10479',),
#  ('L1048',),
#  ('L10480',),
#  ('L10481',),
#  ('L10482',),
#  ('L10483',),
#  ('L10484',),
#  ('L10485',),
#  ('L10486',),
#  ('L10487',),
#  ('L10488',),
#  ('L10489',),
#  ('L1049',),
#  ('L10490',),
#  ('L10491',),
#  ('L10492',),
#  ('L10493',),
#  ('L10494',),
#  ('L10495',),
#  ('L10496',),
#  ('L10497',),
#  ('L10498',),
#  ('L10499',),
#  ('L105',),
#  ('L1050',),
#  ('L10500',),
#  ('L10501',),
#  ('L10502',),
#  ('L10503',),
#  ('L10504',),
#  ('L10505',),
#  ('L10506',),
#  ('L10507',),
#  ('L10508',),
#  ('L10509',),
#  ('L1051',),
#  ('L10510',),
#  ('L10511',),
#  ('L10512',),
#  ('L10513',),
#  ('L10514',),
#  ('L10515',),
#  ('L10516',),
#  ('L10517',),
#  ('L10518',),
#  ('L10519',),
#  ('L1052',),
#  ('L10520',),
#  ('L10521',),
#  ('L10522',),
#  ('L10523',),
#  ('L10524',),
#  ('L10525',),
#  ('L10526',),
#  ('L10527',),
#  ('L10528',),
#  ('L10529',),
#  ('L1053',),
#  ('L10530',),
#  ('L10531',),
#  ('L10532',),
#  ('L10533',),
#  ('L10534',),
#  ('L10535',),
#  ('L10536',),
#  ('L10537',),
#  ('L10538',),
#  ('L10539',),
#  ('L1054',),
#  ('L10540',),
#  ('L10541',),
#  ('L10542',),
#  ('L10543',),
#  ('L10544',),
#  ('L10545',),
#  ('L10546',),
#  ('L10547',),
#  ('L10548',),
#  ('L10549',),
#  ('L1055',),
#  ('L10550',),
#  ('L10551',),
#  ('L10552',),
#  ('L10553',),
#  ('L10554',),
#  ('L10555',),
#  ('L10556',),
#  ('L10557',),
#  ('L10558',),
#  ('L10559',),
#  ('L1056',),
#  ('L10560',),
#  ('L10561',),
#  ('L10562',),
#  ('L10563',),
#  ('L10564',),
#  ('L10565',),
#  ('L10566',),
#  ('L10567',),
#  ('L10568',),
#  ('L10569',),
#  ('L1057',),
#  ('L10570',),
#  ('L10571',),
#  ('L10572',),
#  ('L10573',),
#  ('L10574',),
#  ('L10575',),
#  ('L10576',),
#  ('L10577',),
#  ('L10578',),
#  ('L10579',),
#  ('L1058',),
#  ('L10580',),
#  ('L10581',),
#  ('L10582',),
#  ('L10583',),
#  ('L10584',),
#  ('L10585',),
#  ('L10586',),
#  ('L10587',),
#  ('L10588',),
#  ('L10589',),
#  ('L1059',),
#  ('L10590',),
#  ('L10591',),
#  ('L10592',),
#  ('L10593',),
#  ('L10594',),
#  ('L10595',),
#  ('L10596',),
#  ('L10597',),
#  ('L10598',),
#  ('L10599',),
#  ('L106',),
#  ('L1060',),
#  ('L10600',),
#  ('L10601',),
#  ('L10602',),
#  ('L10603',),
#  ('L10604',),
#  ('L10605',),
#  ('L10606',),
#  ('L10607',),
#  ('L10608',),
#  ('L10609',),
#  ('L1061',),
#  ('L10610',),
#  ('L10611',),
#  ('L10612',),
#  ('L10613',),
#  ('L10614',),
#  ('L10615',),
#  ('L10616',),
#  ('L10617',),
#  ('L10618',),
#  ('L10619',),
#  ('L1062',),
#  ('L10620',),
#  ('L10621',),
#  ('L10622',),
#  ('L10623',),
#  ('L10624',),
#  ('L10625',),
#  ('L10626',),
#  ('L10627',),
#  ('L10628',),
#  ('L10629',),
#  ('L1063',),
#  ('L10630',),
#  ('L10631',),
#  ('L10632',),
#  ('L10633',),
#  ('L10634',),
#  ('L10635',),
#  ('L10636',),
#  ('L10637',),
#  ('L10638',),
#  ('L10639',),
#  ('L1064',),
#  ('L10640',),
#  ('L10641',),
#  ('L10642',),
#  ('L10643',),
#  ('L10644',),
#  ('L10645',),
#  ('L10646',),
#  ('L10647',),
#  ('L10648',),
#  ('L10649',),
#  ('L1065',),
#  ('L10650',),
#  ('L10651',),
#  ('L10652',),
#  ('L10653',),
#  ('L10654',),
#  ('L10655',),
#  ('L10656',),
#  ('L10657',),
#  ('L10658',),
#  ('L10659',),
#  ('L1066',),
#  ('L10660',),
#  ('L10661',),
#  ('L10662',),
#  ('L10663',),
#  ('L10664',),
#  ('L10665',),
#  ('L10666',),
#  ('L10667',),
#  ('L10668',),
#  ('L10669',),
#  ('L1067',),
#  ('L10670',),
#  ('L10671',),
#  ('L10672',),
#  ('L10673',),
#  ('L10674',),
#  ('L10675',),
#  ('L10676',),
#  ('L10677',),
#  ('L10678',),
#  ('L10679',),
#  ('L1068',),
#  ('L10680',),
#  ('L10681',),
#  ('L10682',),
#  ('L10683',),
#  ('L10684',),
#  ('L10685',),
#  ('L10686',),
#  ('L10687',),
#  ('L10688',),
#  ('L10689',),
#  ('L1069',),
#  ('L10690',),
#  ('L10691',),
#  ('L10692',),
#  ('L10693',),
#  ('L10694',),
#  ('L10695',),
#  ('L10696',),
#  ('L10697',),
#  ('L10698',),
#  ('L10699',),
#  ('L107',),
#  ('L1070',),
#  ('L10700',),
#  ('L10701',),
#  ('L10702',),
#  ('L10703',),
#  ('L10704',),
#  ('L10705',),
#  ('L10706',),
#  ('L10707',),
#  ('L10708',),
#  ('L10709',),
#  ('L1071',),
#  ('L10710',),
#  ('L10711',),
#  ('L10712',),
#  ('L10713',),
#  ('L10714',),
#  ('L10715',),
#  ('L10716',),
#  ('L10717',),
#  ('L10718',),
#  ('L10719',),
#  ('L1072',),
#  ('L10720',),
#  ('L10721',),
#  ('L10722',),
#  ('L10723',),
#  ('L10724',),
#  ('L10725',),
#  ('L10726',),
#  ('L10727',),
#  ('L10728',),
#  ('L10729',),
#  ('L1073',),
#  ('L10730',),
#  ('L10731',),
#  ('L10732',),
#  ('L10733',),
#  ('L10734',),
#  ('L10735',),
#  ('L10736',),
#  ('L10737',),
#  ('L10738',),
#  ('L10739',),
#  ('L1074',),
#  ('L10740',),
#  ('L10741',),
#  ('L10742',),
#  ('L10743',),
#  ('L10744',),
#  ('L10745',),
#  ('L10746',),
#  ('L10747',),
#  ('L10748',),
#  ('L10749',),
#  ('L1075',),
#  ('L10750',),
#  ('L10751',),
#  ('L10752',),
#  ('L10753',),
#  ('L10754',),
#  ('L10755',),
#  ('L10756',),
#  ('L10757',),
#  ('L10758',),
#  ('L10759',),
#  ('L1076',),
#  ('L10760',),
#  ('L10761',),
#  ('L10762',),
#  ('L10763',),
#  ('L10764',),
#  ('L10765',),
#  ('L10766',),
#  ('L10767',),
#  ('L10768',),
#  ('L10769',),
#  ('L1077',),
#  ('L10770',),
#  ('L10771',),
#  ('L10772',),
#  ('L10773',),
#  ('L10774',),
#  ('L10775',),
#  ('L10776',),
#  ('L10777',),
#  ('L10778',),
#  ('L10779',),
#  ('L1078',),
#  ('L10780',),
#  ('L10781',),
#  ('L10782',),
#  ('L10783',),
#  ('L10784',),
#  ('L10785',),
#  ('L10786',),
#  ('L10787',),
#  ('L10788',),
#  ('L10789',),
#  ('L1079',),
#  ('L10790',),
#  ('L10791',),
#  ('L10792',),
#  ('L10793',),
#  ('L10794',),
#  ('L10795',),
#  ('L10796',),
#  ('L10797',),
#  ('L10798',),
#  ('L10799',),
#  ('L108',),
#  ('L1080',),
#  ('L10800',),
#  ('L10801',),
#  ('L10802',),
#  ('L10803',),
#  ('L10804',),
#  ('L10805',),
#  ('L10806',),
#  ('L10807',),
#  ('L10808',),
#  ('L10809',),
#  ('L1081',),
#  ('L10810',),
#  ('L10811',),
#  ('L10812',),
#  ('L10813',),
#  ('L10814',),
#  ('L10815',),
#  ('L10816',),
#  ('L10817',),
#  ('L10818',),
#  ('L10819',),
#  ('L1082',),
#  ('L10820',),
#  ('L10821',),
#  ('L10822',),
#  ('L10823',),
#  ('L10824',),
#  ('L10825',),
#  ('L10826',),
#  ('L10827',),
#  ('L10828',),
#  ('L10829',),
#  ('L1083',),
#  ('L10830',),
#  ('L10831',),
#  ('L10832',),
#  ('L10833',),
#  ('L10834',),
#  ('L10835',),
#  ('L10836',),
#  ('L10837',),
#  ('L10838',),
#  ('L10839',),
#  ('L1084',),
#  ('L10840',),
#  ('L10841',),
#  ('L10842',),
#  ('L10843',),
#  ('L10844',),
#  ('L10845',),
#  ('L10846',),
#  ('L10847',),
#  ('L10848',),
#  ('L10849',),
#  ('L1085',),
#  ('L10850',),
#  ('L10851',),
#  ('L10852',),
#  ('L10853',),
#  ('L10854',),
#  ('L10855',),
#  ('L10856',),
#  ('L10857',),
#  ('L10858',),
#  ('L10859',),
#  ('L1086',),
#  ('L10860',),
#  ('L10861',),
#  ('L10862',),
#  ('L10863',),
#  ('L10864',),
#  ('L10865',),
#  ('L10866',),
#  ('L10867',),
#  ('L10868',),
#  ('L10869',),
#  ('L1087',),
#  ('L10870',),
#  ('L10871',),
#  ('L10872',),
#  ('L10873',),
#  ('L10874',),
#  ('L10875',),
#  ('L10876',),
#  ('L10877',),
#  ('L10878',),
#  ('L10879',),
#  ('L1088',),
#  ('L10880',),
#  ('L10881',),
#  ('L10882',),
#  ('L10883',),
#  ('L10884',),
#  ('L10885',),
#  ('L10886',),
#  ('L10887',),
#  ('L10888',),
#  ('L10889',),
#  ('L1089',),
#  ('L10890',),
#  ('L10891',),
#  ('L10892',),
#  ('L10893',),
#  ('L10894',),
#  ('L10895',),
#  ('L10896',),
#  ('L10897',),
#  ('L10898',),
#  ...]

# %% [markdown]
# #### How many properties are in the Watershed table?

# %%
# %%sql
# SELECT ws_property_id, location, property_type, current_monthly_rent
# FROM watershed_property_info
# Out:
# 244 rows affected.
# [('W1', 'L9531', 'R6', 1060),
#  ('W10', 'L9533', 'R6', 1200),
#  ('W100', 'L1944', 'R2', 3300),
#  ('W101', 'L15257', 'R2', 1400),
#  ('W102', 'L15257', 'R6', 2000),
#  ('W103', 'L15257', 'R10', 1600),
#  ('W104', 'L15257', 'R14', 2800),
#  ('W105', 'L15260', 'R2', 1100),
#  ('W106', 'L15260', 'R6', 1900),
#  ('W107', 'L15260', 'R10', 1800),
#  ('W108', 'L15260', 'R14', 3200),
#  ('W109', 'L15264', 'R2', 1000),
#  ('W11', 'L9533', 'R10', 1000),
#  ('W110', 'L15264', 'R6', 1300),
#  ('W111', 'L15264', 'R10', 1200),
#  ('W112', 'L15264', 'R14', 1600),
#  ('W113', 'L15278', 'R2', 800),
#  ('W114', 'L15278', 'R6', 1200),
#  ('W115', 'L15278', 'R10', 900),
#  ('W116', 'L15278', 'R14', 1100),
#  ('W117', 'L15280', 'R2', 1000),
#  ('W118', 'L15280', 'R6', 1400),
#  ('W119', 'L15280', 'R10', 1500),
#  ('W12', 'L9533', 'R14', 1300),
#  ('W120', 'L15280', 'R14', 1600),
#  ('W121', 'L463', 'R2', 600),
#  ('W122', 'L463', 'R6', 800),
#  ('W123', 'L463', 'R10', 700),
#  ('W124', 'L463', 'R14', 1000),
#  ('W125', 'L464', 'R2', 700),
#  ('W126', 'L464', 'R6', 900),
#  ('W127', 'L464', 'R10', 1000),
#  ('W128', 'L464', 'R14', 1200),
#  ('W129', 'L2314', 'R2', 1200),
#  ('W13', 'L9534', 'R6', 920),
#  ('W130', 'L2314', 'R6', 1300),
#  ('W131', 'L2314', 'R10', 1100),
#  ('W132', 'L2314', 'R14', 1200),
#  ('W133', 'L2318', 'R2', 1300),
#  ('W134', 'L2318', 'R6', 1700),
#  ('W135', 'L2318', 'R10', 1200),
#  ('W136', 'L2318', 'R14', 1900),
#  ('W137', 'L2323', 'R2', 1000),
#  ('W138', 'L2323', 'R6', 1500),
#  ('W139', 'L2323', 'R10', 1300),
#  ('W14', 'L9534', 'R10', 850),
#  ('W140', 'L2323', 'R14', 1800),
#  ('W141', 'L2325', 'R2', 1100),
#  ('W142', 'L2325', 'R6', 1400),
#  ('W143', 'L2325', 'R10', 1300),
#  ('W144', 'L2325', 'R14', 1900),
#  ('W145', 'L2338', 'R2', 900),
#  ('W146', 'L2338', 'R6', 1400),
#  ('W147', 'L2338', 'R10', 1400),
#  ('W148', 'L2338', 'R14', 1700),
#  ('W149', 'L3244', 'R2', 800),
#  ('W15', 'L9534', 'R14', 900),
#  ('W150', 'L3244', 'R6', 1300),
#  ('W151', 'L3244', 'R10', 1400),
#  ('W152', 'L3244', 'R14', 1900),
#  ('W153', 'L3256', 'R2', 1700),
#  ('W154', 'L3256', 'R6', 2400),
#  ('W155', 'L3256', 'R10', 2100),
#  ('W156', 'L3256', 'R14', 3200),
#  ('W157', 'L3261', 'R2', 1300),
#  ('W158', 'L3261', 'R6', 1700),
#  ('W159', 'L3261', 'R10', 1400),
#  ('W16', 'L9534', 'R2', 750),
#  ('W160', 'L3261', 'R14', 1900),
#  ('W161', 'L3262', 'R2', 1600),
#  ('W162', 'L3262', 'R6', 2200),
#  ('W163', 'L3262', 'R10', 1500),
#  ('W164', 'L3262', 'R14', 2400),
#  ('W165', 'L3264', 'R2', 1600),
#  ('W166', 'L3264', 'R6', 1900),
#  ('W167', 'L3264', 'R10', 1400),
#  ('W168', 'L3264', 'R14', 2000),
#  ('W169', 'L10126', 'R2', 1000),
#  ('W17', 'L4761', 'R6', 2500),
#  ('W170', 'L10126', 'R6', 1400),
#  ('W171', 'L10126', 'R10', 1300),
#  ('W172', 'L10126', 'R14', 1800),
#  ('W173', 'L10130', 'R2', 700),
#  ('W174', 'L10130', 'R6', 900),
#  ('W175', 'L10130', 'R10', 1000),
#  ('W176', 'L10130', 'R14', 1200),
#  ('W177', 'L10133', 'R2', 700),
#  ('W178', 'L10133', 'R6', 1000),
#  ('W179', 'L10133', 'R10', 800),
#  ('W18', 'L4761', 'R10', 2500),
#  ('W180', 'L10133', 'R14', 900),
#  ('W181', 'L10136', 'R2', 700),
#  ('W182', 'L10136', 'R6', 1000),
#  ('W183', 'L10136', 'R10', 900),
#  ('W184', 'L10136', 'R14', 1200),
#  ('W185', 'L1882', 'R2', 1100),
#  ('W186', 'L1882', 'R6', 1400),
#  ('W187', 'L1882', 'R10', 1300),
#  ('W188', 'L1882', 'R14', 1900),
#  ('W189', 'L1883', 'R2', 900),
#  ('W19', 'L4761', 'R14', 2800),
#  ('W190', 'L1883', 'R6', 1100),
#  ('W191', 'L1883', 'R10', 1300),
#  ('W192', 'L1883', 'R14', 1600),
#  ('W193', 'L1887', 'R2', 1400),
#  ('W194', 'L1887', 'R6', 2000),
#  ('W195', 'L1887', 'R10', 1700),
#  ('W196', 'L1887', 'R14', 2500),
#  ('W197', 'L1902', 'R2', 1800),
#  ('W198', 'L1902', 'R6', 2600),
#  ('W199', 'L1902', 'R10', 2500),
#  ('W2', 'L9531', 'R10', 1500),
#  ('W20', 'L4761', 'R2', 1700),
#  ('W200', 'L1902', 'R14', 3600),
#  ('W201', 'L1916', 'R2', 1200),
#  ('W202', 'L1916', 'R6', 1600),
#  ('W203', 'L1916', 'R10', 1000),
#  ('W204', 'L1916', 'R14', 1500),
#  ('W205', 'L12252', 'R2', 750),
#  ('W206', 'L12252', 'R6', 1040),
#  ('W207', 'L12252', 'R10', 900),
#  ('W208', 'L12252', 'R14', 1400),
#  ('W209', 'L12260', 'R2', 825),
#  ('W21', 'L4765', 'R6', 2700),
#  ('W210', 'L12260', 'R6', 1300),
#  ('W211', 'L12260', 'R10', 1000),
#  ('W212', 'L12260', 'R14', 1480),
#  ('W213', 'L12264', 'R2', 650),
#  ('W214', 'L12264', 'R6', 920),
#  ('W215', 'L12264', 'R10', 880),
#  ('W216', 'L12264', 'R14', 1200),
#  ('W217', 'L16888', 'R2', 1000),
#  ('W218', 'L16888', 'R6', 1200),
#  ('W219', 'L16888', 'R10', 1400),
#  ('W22', 'L4765', 'R10', 2700),
#  ('W220', 'L16888', 'R14', 1600),
#  ('W221', 'L16887', 'R2', 1105),
#  ('W222', 'L16887', 'R6', 1665),
#  ('W223', 'L16887', 'R10', 1175),
#  ('W224', 'L16887', 'R14', 1725),
#  ('W225', 'L16898', 'R2', 709),
#  ('W226', 'L16898', 'R6', 869),
#  ('W227', 'L16898', 'R10', 925),
#  ('W228', 'L16898', 'R14', 1350),
#  ('W229', 'L16890', 'R2', 900),
#  ('W23', 'L4765', 'R14', 3200),
#  ('W230', 'L16890', 'R6', 1325),
#  ('W231', 'L16890', 'R10', 975),
#  ('W232', 'L16890', 'R14', 1550),
#  ('W233', 'L14416', 'R2', 1165),
#  ('W234', 'L14416', 'R6', 1625),
#  ('W235', 'L14416', 'R10', 1400),
#  ('W236', 'L14416', 'R14', 1995),
#  ('W237', 'L14418', 'R2', 760),
#  ('W238', 'L14418', 'R6', 965),
#  ('W239', 'L14418', 'R10', 1185),
#  ('W24', 'L4765', 'R2', 1700),
#  ('W240', 'L14418', 'R14', 1340),
#  ('W241', 'L14419', 'R2', 1150),
#  ('W242', 'L14419', 'R6', 2000),
#  ('W243', 'L14419', 'R10', 1600),
#  ('W244', 'L14419', 'R14', 2150),
#  ('W25', 'L4770', 'R2', 1600),
#  ('W26', 'L4770', 'R6', 2100),
#  ('W27', 'L4770', 'R10', 1200),
#  ('W28', 'L4770', 'R14', 2100),
#  ('W29', 'L4794', 'R6', 2500),
#  ('W3', 'L9531', 'R14', 2000),
#  ('W30', 'L4794', 'R10', 2500),
#  ('W31', 'L4794', 'R14', 2750),
#  ('W32', 'L4794', 'R2', 1800),
#  ('W33', 'L4804', 'R6', 3000),
#  ('W34', 'L4804', 'R10', 2000),
#  ('W35', 'L4804', 'R14', 2950),
#  ('W36', 'L4804', 'R2', 1700),
#  ('W37', 'L11419', 'R2', 3000),
#  ('W38', 'L11419', 'R6', 3200),
#  ('W39', 'L11421', 'R6', 4500),
#  ('W4', 'L9531', 'R2', 800),
#  ('W40', 'L11421', 'R10', 4500),
#  ('W41', 'L11421', 'R14', 5500),
#  ('W42', 'L11421', 'R2', 3500),
#  ('W43', 'L11427', 'R6', 4000),
#  ('W44', 'L11427', 'R2', 3000),
#  ('W45', 'L11431', 'R6', 5600),
#  ('W46', 'L11431', 'R10', 3200),
#  ('W47', 'L11431', 'R14', 3500),
#  ('W48', 'L11431', 'R2', 3400),
#  ('W49', 'L11434', 'R6', 4200),
#  ('W5', 'L9532', 'R6', 1100),
#  ('W50', 'L11434', 'R10', 3000),
#  ('W51', 'L11434', 'R14', 3900),
#  ('W52', 'L11434', 'R2', 3600),
#  ('W53', 'L11480', 'R6', 3500),
#  ('W54', 'L11480', 'R10', 2500),
#  ('W55', 'L11480', 'R14', 3000),
#  ('W56', 'L11480', 'R2', 3000),
#  ('W57', 'L11495', 'R6', 3900),
#  ('W58', 'L11495', 'R10', 2800),
#  ('W59', 'L11495', 'R14', 3500),
#  ('W6', 'L9532', 'R10', 900),
#  ('W60', 'L11495', 'R2', 2600),
#  ('W61', 'L1734', 'R6', 2695),
#  ('W62', 'L1734', 'R10', 3000),
#  ('W63', 'L1734', 'R14', 4000),
#  ('W64', 'L1734', 'R2', 2295),
#  ('W65', 'L1735', 'R6', 3000),
#  ('W66', 'L1735', 'R10', 3300),
#  ('W67', 'L1735', 'R14', 4500),
#  ('W68', 'L1735', 'R2', 2700),
#  ('W69', 'L1736', 'R2', 2700),
#  ('W7', 'L9532', 'R14', 1100),
#  ('W70', 'L1736', 'R6', 3000),
#  ('W71', 'L1736', 'R10', 4500),
#  ('W72', 'L1736', 'R14', 4900),
#  ('W73', 'L1737', 'R6', 3300),
#  ('W74', 'L1737', 'R10', 4500),
#  ('W75', 'L1737', 'R14', 4200),
#  ('W76', 'L1737', 'R2', 2500),
#  ('W77', 'L1738', 'R2', 2500),
#  ('W78', 'L1738', 'R6', 3300),
#  ('W79', 'L1738', 'R10', 4500),
#  ('W8', 'L9532', 'R2', 500),
#  ('W80', 'L1738', 'R14', 4200),
#  ('W81', 'L1940', 'R6', 3600),
#  ('W82', 'L1940', 'R10', 4000),
#  ('W83', 'L1940', 'R14', 5500),
#  ('W84', 'L1940', 'R2', 3000),
#  ('W85', 'L1941', 'R6', 4000),
#  ('W86', 'L1941', 'R10', 4000),
#  ('W87', 'L1941', 'R14', 5000),
#  ('W88', 'L1941', 'R2', 3200),
#  ('W89', 'L1942', 'R6', 3500),
#  ('W9', 'L9533', 'R2', 965),
#  ('W90', 'L1942', 'R10', 3200),
#  ('W91', 'L1942', 'R14', 3500),
#  ('W92', 'L1942', 'R2', 3000),
#  ('W93', 'L1943', 'R2', 2600),
#  ('W94', 'L1943', 'R6', 4000),
#  ('W95', 'L1943', 'R10', 4000),
#  ('W96', 'L1943', 'R14', 5100),
#  ('W97', 'L1944', 'R6', 5600),
#  ('W98', 'L1944', 'R10', 5000),
#  ('W99', 'L1944', 'R14', 6000)]

# %% [markdown]
# #### How many properties are in the short-term rental table?

# %%
# %%sql
# SELECT st_property_id, location, property_type
# FROM st_property_info
# Out:
# 999 rows affected.
# [('ST1', 'L9531', 'R6'),
#  ('ST10', 'L9533', 'R6'),
#  ('ST100', 'L1944', 'R2'),
#  ('ST1000', 'L5957', 'R1'),
#  ('ST101', 'L15257', 'R2'),
#  ('ST102', 'L15257', 'R6'),
#  ('ST103', 'L15257', 'R10'),
#  ('ST104', 'L15257', 'R14'),
#  ('ST105', 'L15260', 'R2'),
#  ('ST106', 'L15260', 'R6'),
#  ('ST107', 'L15260', 'R10'),
#  ('ST108', 'L15260', 'R14'),
#  ('ST109', 'L15264', 'R2'),
#  ('ST11', 'L9533', 'R10'),
#  ('ST110', 'L15264', 'R6'),
#  ('ST111', 'L15264', 'R10'),
#  ('ST112', 'L15264', 'R14'),
#  ('ST113', 'L15278', 'R2'),
#  ('ST114', 'L15278', 'R6'),
#  ('ST115', 'L15278', 'R10'),
#  ('ST116', 'L15278', 'R14'),
#  ('ST117', 'L15280', 'R2'),
#  ('ST118', 'L15280', 'R6'),
#  ('ST119', 'L15280', 'R10'),
#  ('ST12', 'L9533', 'R14'),
#  ('ST120', 'L15280', 'R14'),
#  ('ST121', 'L463', 'R2'),
#  ('ST122', 'L463', 'R6'),
#  ('ST123', 'L463', 'R10'),
#  ('ST124', 'L463', 'R14'),
#  ('ST125', 'L464', 'R2'),
#  ('ST126', 'L464', 'R6'),
#  ('ST127', 'L464', 'R10'),
#  ('ST128', 'L464', 'R14'),
#  ('ST129', 'L2314', 'R2'),
#  ('ST13', 'L9534', 'R6'),
#  ('ST130', 'L2314', 'R6'),
#  ('ST131', 'L2314', 'R10'),
#  ('ST132', 'L2314', 'R14'),
#  ('ST133', 'L2318', 'R2'),
#  ('ST134', 'L2318', 'R6'),
#  ('ST135', 'L2318', 'R10'),
#  ('ST136', 'L2318', 'R14'),
#  ('ST137', 'L2323', 'R2'),
#  ('ST138', 'L2323', 'R6'),
#  ('ST139', 'L2323', 'R10'),
#  ('ST14', 'L9534', 'R10'),
#  ('ST140', 'L2323', 'R14'),
#  ('ST141', 'L2325', 'R2'),
#  ('ST142', 'L2325', 'R6'),
#  ('ST143', 'L2325', 'R10'),
#  ('ST144', 'L2325', 'R14'),
#  ('ST145', 'L2338', 'R2'),
#  ('ST146', 'L2338', 'R6'),
#  ('ST147', 'L2338', 'R10'),
#  ('ST148', 'L2338', 'R14'),
#  ('ST149', 'L3244', 'R2'),
#  ('ST15', 'L9534', 'R14'),
#  ('ST150', 'L3244', 'R6'),
#  ('ST151', 'L3244', 'R10'),
#  ('ST152', 'L3244', 'R14'),
#  ('ST153', 'L3256', 'R2'),
#  ('ST154', 'L3256', 'R6'),
#  ('ST155', 'L3256', 'R10'),
#  ('ST156', 'L3256', 'R14'),
#  ('ST157', 'L3261', 'R2'),
#  ('ST158', 'L3261', 'R6'),
#  ('ST159', 'L3261', 'R10'),
#  ('ST16', 'L9534', 'R2'),
#  ('ST160', 'L3261', 'R14'),
#  ('ST161', 'L3262', 'R2'),
#  ('ST162', 'L3262', 'R6'),
#  ('ST163', 'L3262', 'R10'),
#  ('ST164', 'L3262', 'R14'),
#  ('ST165', 'L3264', 'R2'),
#  ('ST166', 'L3264', 'R6'),
#  ('ST167', 'L3264', 'R10'),
#  ('ST168', 'L3264', 'R14'),
#  ('ST169', 'L10126', 'R2'),
#  ('ST17', 'L4761', 'R6'),
#  ('ST170', 'L10126', 'R6'),
#  ('ST171', 'L10126', 'R10'),
#  ('ST172', 'L10126', 'R14'),
#  ('ST173', 'L10130', 'R2'),
#  ('ST174', 'L10130', 'R6'),
#  ('ST175', 'L10130', 'R10'),
#  ('ST176', 'L10130', 'R14'),
#  ('ST177', 'L10133', 'R2'),
#  ('ST178', 'L10133', 'R6'),
#  ('ST179', 'L10133', 'R10'),
#  ('ST18', 'L4761', 'R10'),
#  ('ST180', 'L10133', 'R14'),
#  ('ST181', 'L10136', 'R2'),
#  ('ST182', 'L10136', 'R6'),
#  ('ST183', 'L10136', 'R10'),
#  ('ST184', 'L10136', 'R14'),
#  ('ST185', 'L1882', 'R2'),
#  ('ST186', 'L1882', 'R6'),
#  ('ST187', 'L1882', 'R10'),
#  ('ST188', 'L1882', 'R3'),
#  ('ST189', 'L1883', 'R13'),
#  ('ST19', 'L4761', 'R14'),
#  ('ST190', 'L1883', 'R1'),
#  ('ST191', 'L1883', 'R10'),
#  ('ST192', 'L1883', 'R14'),
#  ('ST193', 'L1887', 'R2'),
#  ('ST194', 'L1887', 'R6'),
#  ('ST195', 'L1887', 'R10'),
#  ('ST196', 'L1887', 'R14'),
#  ('ST197', 'L1902', 'R2'),
#  ('ST198', 'L1902', 'R6'),
#  ('ST199', 'L1902', 'R10'),
#  ('ST2', 'L9531', 'R10'),
#  ('ST20', 'L4761', 'R2'),
#  ('ST200', 'L1902', 'R14'),
#  ('ST201', 'L1916', 'R2'),
#  ('ST202', 'L1916', 'R6'),
#  ('ST203', 'L1916', 'R10'),
#  ('ST204', 'L1916', 'R14'),
#  ('ST205', 'L12252', 'R2'),
#  ('ST206', 'L12252', 'R6'),
#  ('ST207', 'L12252', 'R10'),
#  ('ST208', 'L12252', 'R14'),
#  ('ST209', 'L12260', 'R2'),
#  ('ST21', 'L4765', 'R6'),
#  ('ST210', 'L12260', 'R6'),
#  ('ST211', 'L12260', 'R10'),
#  ('ST212', 'L12260', 'R1'),
#  ('ST213', 'L12264', 'R4'),
#  ('ST214', 'L12264', 'R4'),
#  ('ST215', 'L12264', 'R1'),
#  ('ST216', 'L12264', 'R7'),
#  ('ST217', 'L16888', 'R8'),
#  ('ST218', 'L16888', 'R6'),
#  ('ST219', 'L16888', 'R10'),
#  ('ST22', 'L4765', 'R1'),
#  ('ST220', 'L16888', 'R14'),
#  ('ST221', 'L16887', 'R2'),
#  ('ST222', 'L16887', 'R6'),
#  ('ST223', 'L16887', 'R10'),
#  ('ST224', 'L16887', 'R14'),
#  ('ST225', 'L16898', 'R2'),
#  ('ST226', 'L16898', 'R6'),
#  ('ST227', 'L16898', 'R10'),
#  ('ST228', 'L16898', 'R14'),
#  ('ST229', 'L16890', 'R2'),
#  ('ST23', 'L4765', 'R5'),
#  ('ST230', 'L16890', 'R6'),
#  ('ST231', 'L16890', 'R10'),
#  ('ST232', 'L16890', 'R14'),
#  ('ST233', 'L14416', 'R7'),
#  ('ST234', 'L14416', 'R8'),
#  ('ST235', 'L14416', 'R10'),
#  ('ST236', 'L14416', 'R14'),
#  ('ST237', 'L14418', 'R2'),
#  ('ST238', 'L14418', 'R6'),
#  ('ST239', 'L14418', 'R10'),
#  ('ST24', 'L4765', 'R16'),
#  ('ST240', 'L14418', 'R14'),
#  ('ST241', 'L14419', 'R2'),
#  ('ST242', 'L14419', 'R6'),
#  ('ST243', 'L14419', 'R10'),
#  ('ST244', 'L14419', 'R14'),
#  ('ST245', 'L18168', 'R4'),
#  ('ST246', 'L12651', 'R12'),
#  ('ST247', 'L14129', 'R16'),
#  ('ST248', 'L9526', 'R8'),
#  ('ST249', 'L16463', 'R4'),
#  ('ST25', 'L4770', 'R7'),
#  ('ST250', 'L2926', 'R9'),
#  ('ST251', 'L13927', 'R9'),
#  ('ST252', 'L13182', 'R8'),
#  ('ST253', 'L9440', 'R1'),
#  ('ST254', 'L1882', 'R7'),
#  ('ST255', 'L16573', 'R15'),
#  ('ST256', 'L8234', 'R15'),
#  ('ST257', 'L5257', 'R11'),
#  ('ST258', 'L18040', 'R16'),
#  ('ST259', 'L13288', 'R3'),
#  ('ST26', 'L4770', 'R1'),
#  ('ST260', 'L11609', 'R7'),
#  ('ST261', 'L1532', 'R8'),
#  ('ST262', 'L3248', 'R16'),
#  ('ST263', 'L10078', 'R7'),
#  ('ST264', 'L8616', 'R4'),
#  ('ST265', 'L15033', 'R4'),
#  ('ST266', 'L337', 'R3'),
#  ('ST267', 'L18143', 'R8'),
#  ('ST268', 'L14892', 'R7'),
#  ('ST269', 'L12500', 'R16'),
#  ('ST27', 'L4770', 'R5'),
#  ('ST270', 'L15383', 'R4'),
#  ('ST271', 'L10046', 'R4'),
#  ('ST272', 'L910', 'R5'),
#  ('ST273', 'L15619', 'R8'),
#  ('ST274', 'L6791', 'R11'),
#  ('ST275', 'L10758', 'R7'),
#  ('ST276', 'L18023', 'R15'),
#  ('ST277', 'L8940', 'R15'),
#  ('ST278', 'L5592', 'R5'),
#  ('ST279', 'L11377', 'R8'),
#  ('ST28', 'L4770', 'R16'),
#  ('ST280', 'L17825', 'R4'),
#  ('ST281', 'L7592', 'R7'),
#  ('ST282', 'L6398', 'R15'),
#  ('ST283', 'L6916', 'R13'),
#  ('ST284', 'L13997', 'R9'),
#  ('ST285', 'L10339', 'R4'),
#  ('ST286', 'L5218', 'R3'),
#  ('ST287', 'L3015', 'R4'),
#  ('ST288', 'L2424', 'R7'),
#  ('ST289', 'L13082', 'R4'),
#  ('ST29', 'L4794', 'R7'),
#  ('ST290', 'L5169', 'R15'),
#  ('ST291', 'L15700', 'R5'),
#  ('ST292', 'L6958', 'R16'),
#  ('ST293', 'L17610', 'R16'),
#  ('ST294', 'L6588', 'R16'),
#  ('ST295', 'L11784', 'R13'),
#  ('ST296', 'L4322', 'R16'),
#  ('ST297', 'L11399', 'R13'),
#  ('ST298', 'L186', 'R16'),
#  ('ST299', 'L9096', 'R12'),
#  ('ST3', 'L9531', 'R14'),
#  ('ST30', 'L4794', 'R3'),
#  ('ST300', 'L5448', 'R11'),
#  ('ST301', 'L4932', 'R16'),
#  ('ST302', 'L3464', 'R9'),
#  ('ST303', 'L14193', 'R15'),
#  ('ST304', 'L16352', 'R1'),
#  ('ST305', 'L5609', 'R5'),
#  ('ST306', 'L12020', 'R16'),
#  ('ST307', 'L3310', 'R8'),
#  ('ST308', 'L15437', 'R5'),
#  ('ST309', 'L8388', 'R16'),
#  ('ST31', 'L4794', 'R14'),
#  ('ST310', 'L15653', 'R3'),
#  ('ST311', 'L4772', 'R7'),
#  ('ST312', 'L1821', 'R8'),
#  ('ST313', 'L1567', 'R4'),
#  ('ST314', 'L16007', 'R5'),
#  ('ST315', 'L4030', 'R9'),
#  ('ST316', 'L17781', 'R1'),
#  ('ST317', 'L2326', 'R5'),
#  ('ST318', 'L7760', 'R8'),
#  ('ST319', 'L12003', 'R5'),
#  ('ST32', 'L4794', 'R2'),
#  ('ST320', 'L15202', 'R5'),
#  ('ST321', 'L6502', 'R11'),
#  ('ST322', 'L16048', 'R5'),
#  ('ST323', 'L2148', 'R13'),
#  ('ST324', 'L15039', 'R8'),
#  ('ST325', 'L4178', 'R11'),
#  ('ST326', 'L11783', 'R5'),
#  ('ST327', 'L3635', 'R5'),
#  ('ST328', 'L952', 'R13'),
#  ('ST329', 'L16999', 'R9'),
#  ('ST33', 'L4804', 'R6'),
#  ('ST330', 'L13027', 'R3'),
#  ('ST331', 'L7980', 'R16'),
#  ('ST332', 'L4076', 'R4'),
#  ('ST333', 'L9864', 'R9'),
#  ('ST334', 'L14609', 'R9'),
#  ('ST335', 'L2202', 'R1'),
#  ('ST336', 'L6528', 'R13'),
#  ('ST337', 'L17429', 'R11'),
#  ('ST338', 'L13004', 'R7'),
#  ('ST339', 'L12406', 'R4'),
#  ('ST34', 'L4804', 'R10'),
#  ('ST340', 'L3880', 'R3'),
#  ('ST341', 'L13287', 'R9'),
#  ('ST342', 'L16620', 'R1'),
#  ('ST343', 'L11099', 'R16'),
#  ('ST344', 'L4575', 'R9'),
#  ('ST345', 'L2806', 'R11'),
#  ('ST346', 'L5505', 'R11'),
#  ('ST347', 'L8316', 'R1'),
#  ('ST348', 'L7511', 'R8'),
#  ('ST349', 'L1430', 'R4'),
#  ('ST35', 'L4804', 'R14'),
#  ('ST350', 'L2144', 'R15'),
#  ('ST351', 'L10504', 'R12'),
#  ('ST352', 'L15961', 'R5'),
#  ('ST353', 'L4983', 'R12'),
#  ('ST354', 'L11863', 'R9'),
#  ('ST355', 'L11480', 'R14'),
#  ('ST356', 'L11480', 'R2'),
#  ('ST357', 'L11495', 'R6'),
#  ('ST358', 'L11495', 'R10'),
#  ('ST359', 'L11495', 'R14'),
#  ('ST36', 'L4804', 'R2'),
#  ('ST360', 'L11495', 'R2'),
#  ('ST361', 'L1734', 'R6'),
#  ('ST362', 'L1734', 'R10'),
#  ('ST363', 'L1734', 'R14'),
#  ('ST364', 'L1734', 'R2'),
#  ('ST365', 'L1735', 'R6'),
#  ('ST366', 'L1735', 'R10'),
#  ('ST367', 'L11906', 'R12'),
#  ('ST368', 'L16334', 'R4'),
#  ('ST369', 'L624', 'R9'),
#  ('ST37', 'L11419', 'R2'),
#  ('ST370', 'L2968', 'R7'),
#  ('ST371', 'L17281', 'R7'),
#  ('ST372', 'L14264', 'R15'),
#  ('ST373', 'L11948', 'R16'),
#  ('ST374', 'L3762', 'R13'),
#  ('ST375', 'L13497', 'R8'),
#  ('ST376', 'L1136', 'R7'),
#  ('ST377', 'L16754', 'R13'),
#  ('ST378', 'L10563', 'R9'),
#  ('ST379', 'L450', 'R15'),
#  ('ST38', 'L11419', 'R6'),
#  ('ST380', 'L6536', 'R15'),
#  ('ST381', 'L15845', 'R5'),
#  ('ST382', 'L13953', 'R16'),
#  ('ST383', 'L11488', 'R5'),
#  ('ST384', 'L15387', 'R7'),
#  ('ST385', 'L9261', 'R7'),
#  ('ST386', 'L1765', 'R11'),
#  ('ST387', 'L9113', 'R4'),
#  ('ST388', 'L2066', 'R7'),
#  ('ST389', 'L5434', 'R16'),
#  ('ST39', 'L11421', 'R6'),
#  ('ST390', 'L15771', 'R13'),
#  ('ST391', 'L13468', 'R11'),
#  ('ST392', 'L17267', 'R8'),
#  ('ST393', 'L6984', 'R16'),
#  ('ST394', 'L13142', 'R15'),
#  ('ST395', 'L14911', 'R16'),
#  ('ST396', 'L5617', 'R8'),
#  ('ST397', 'L1483', 'R7'),
#  ('ST398', 'L13208', 'R3'),
#  ('ST399', 'L12925', 'R13'),
#  ('ST4', 'L9531', 'R2'),
#  ('ST40', 'L11421', 'R10'),
#  ('ST400', 'L14368', 'R11'),
#  ('ST401', 'L12193', 'R3'),
#  ('ST402', 'L10290', 'R5'),
#  ('ST403', 'L14113', 'R1'),
#  ('ST404', 'L8938', 'R4'),
#  ('ST405', 'L3634', 'R5'),
#  ('ST406', 'L1308', 'R12'),
#  ('ST407', 'L1078', 'R12'),
#  ('ST408', 'L10332', 'R11'),
#  ('ST409', 'L8020', 'R8'),
#  ('ST41', 'L11421', 'R14'),
#  ('ST410', 'L13055', 'R8'),
#  ('ST411', 'L16399', 'R1'),
#  ('ST412', 'L16642', 'R12'),
#  ('ST413', 'L4720', 'R8'),
#  ('ST414', 'L9488', 'R13'),
#  ('ST415', 'L18054', 'R3'),
#  ('ST416', 'L3783', 'R16'),
#  ('ST417', 'L313', 'R9'),
#  ('ST418', 'L12274', 'R7'),
#  ('ST419', 'L7946', 'R15'),
#  ('ST42', 'L11421', 'R2'),
#  ('ST420', 'L6989', 'R7'),
#  ('ST421', 'L11742', 'R11'),
#  ('ST422', 'L4765', 'R10'),
#  ('ST423', 'L4765', 'R14'),
#  ('ST424', 'L4765', 'R2'),
#  ('ST425', 'L4770', 'R2'),
#  ('ST426', 'L4770', 'R6'),
#  ('ST427', 'L4770', 'R10'),
#  ('ST428', 'L4770', 'R14'),
#  ('ST429', 'L4794', 'R6'),
#  ('ST43', 'L11427', 'R6'),
#  ('ST430', 'L4794', 'R10'),
#  ('ST431', 'L837', 'R12'),
#  ('ST432', 'L2809', 'R11'),
#  ('ST433', 'L13196', 'R4'),
#  ('ST434', 'L6667', 'R1'),
#  ('ST435', 'L11802', 'R3'),
#  ('ST436', 'L9258', 'R9'),
#  ('ST437', 'L12234', 'R12'),
#  ('ST438', 'L11639', 'R16'),
#  ('ST439', 'L3830', 'R4'),
#  ('ST44', 'L11427', 'R2'),
#  ('ST440', 'L14451', 'R9'),
#  ('ST441', 'L11761', 'R5'),
#  ('ST442', 'L15133', 'R7'),
#  ('ST443', 'L12675', 'R13'),
#  ('ST444', 'L2431', 'R15'),
#  ('ST445', 'L15527', 'R12'),
#  ('ST446', 'L14795', 'R3'),
#  ('ST447', 'L7137', 'R3'),
#  ('ST448', 'L17367', 'R12'),
#  ('ST449', 'L2599', 'R3'),
#  ('ST45', 'L11431', 'R6'),
#  ('ST450', 'L9005', 'R16'),
#  ('ST451', 'L15691', 'R15'),
#  ('ST452', 'L10373', 'R7'),
#  ('ST453', 'L10048', 'R15'),
#  ('ST454', 'L8528', 'R11'),
#  ('ST455', 'L12067', 'R5'),
#  ('ST456', 'L2775', 'R9'),
#  ('ST457', 'L12388', 'R5'),
#  ('ST458', 'L15429', 'R4'),
#  ('ST459', 'L2737', 'R9'),
#  ('ST46', 'L11431', 'R10'),
#  ('ST460', 'L1891', 'R11'),
#  ('ST461', 'L11027', 'R1'),
#  ('ST462', 'L11378', 'R7'),
#  ('ST463', 'L4536', 'R15'),
#  ('ST464', 'L15902', 'R3'),
#  ('ST465', 'L4775', 'R3'),
#  ('ST466', 'L16790', 'R15'),
#  ('ST467', 'L3833', 'R1'),
#  ('ST468', 'L4052', 'R9'),
#  ('ST469', 'L7896', 'R1'),
#  ('ST47', 'L11431', 'R14'),
#  ('ST470', 'L8488', 'R1'),
#  ('ST471', 'L17269', 'R7'),
#  ('ST472', 'L721', 'R5'),
#  ('ST473', 'L13619', 'R1'),
#  ('ST474', 'L14874', 'R3'),
#  ('ST475', 'L18196', 'R5'),
#  ('ST476', 'L73', 'R13'),
#  ('ST477', 'L482', 'R7'),
#  ('ST478', 'L4348', 'R8'),
#  ('ST479', 'L4583', 'R15'),
#  ('ST48', 'L11431', 'R2'),
#  ('ST480', 'L4355', 'R11'),
#  ('ST481', 'L503', 'R3'),
#  ('ST482', 'L6324', 'R3'),
#  ('ST483', 'L2381', 'R13'),
#  ('ST484', 'L3431', 'R15'),
#  ('ST485', 'L3248', 'R3'),
#  ('ST486', 'L12740', 'R4'),
#  ('ST487', 'L11645', 'R8'),
#  ('ST488', 'L1882', 'R14'),
#  ('ST489', 'L1883', 'R2'),
#  ('ST49', 'L11434', 'R6'),
#  ('ST490', 'L1883', 'R6'),
#  ('ST491', 'L1774', 'R12'),
#  ('ST492', 'L14970', 'R12'),
#  ('ST493', 'L14917', 'R1'),
#  ('ST494', 'L9067', 'R16'),
#  ('ST495', 'L1422', 'R1'),
#  ('ST496', 'L12135', 'R15'),
#  ('ST497', 'L7432', 'R16'),
#  ('ST498', 'L17438', 'R16'),
#  ('ST499', 'L2327', 'R5'),
#  ('ST5', 'L9532', 'R6'),
#  ('ST50', 'L11434', 'R10'),
#  ('ST500', 'L12465', 'R3'),
#  ('ST501', 'L9213', 'R13'),
#  ('ST502', 'L14153', 'R12'),
#  ('ST503', 'L5377', 'R16'),
#  ('ST504', 'L714', 'R3'),
#  ('ST505', 'L16638', 'R16'),
#  ('ST506', 'L12257', 'R4'),
#  ('ST507', 'L10707', 'R16'),
#  ('ST508', 'L12462', 'R8'),
#  ('ST509', 'L7844', 'R11'),
#  ('ST51', 'L11434', 'R14'),
#  ('ST510', 'L8855', 'R3'),
#  ('ST511', 'L11421', 'R1'),
#  ('ST512', 'L12260', 'R14'),
#  ('ST513', 'L12264', 'R2'),
#  ('ST514', 'L12264', 'R6'),
#  ('ST515', 'L12264', 'R10'),
#  ('ST516', 'L12264', 'R14'),
#  ('ST517', 'L16888', 'R2'),
#  ('ST519', 'L14416', 'R2'),
#  ('ST52', 'L11434', 'R2'),
#  ('ST520', 'L14416', 'R6'),
#  ('ST521', 'L14323', 'R12'),
#  ('ST522', 'L9238', 'R8'),
#  ('ST523', 'L8526', 'R4'),
#  ('ST524', 'L17036', 'R4'),
#  ('ST525', 'L7533', 'R9'),
#  ('ST526', 'L1589', 'R7'),
#  ('ST527', 'L11488', 'R9'),
#  ('ST528', 'L7377', 'R8'),
#  ('ST529', 'L15884', 'R13'),
#  ('ST53', 'L11480', 'R6'),
#  ('ST530', 'L8758', 'R13'),
#  ('ST531', 'L2467', 'R3'),
#  ('ST532', 'L2672', 'R11'),
#  ('ST533', 'L17032', 'R9'),
#  ('ST534', 'L744', 'R16'),
#  ('ST535', 'L12990', 'R16'),
#  ('ST536', 'L4311', 'R12'),
#  ('ST537', 'L10386', 'R9'),
#  ('ST538', 'L516', 'R11'),
#  ('ST539', 'L454', 'R9'),
#  ('ST54', 'L11480', 'R10'),
#  ('ST540', 'L11050', 'R11'),
#  ('ST541', 'L6033', 'R11'),
#  ('ST542', 'L13387', 'R9'),
#  ('ST543', 'L17385', 'R5'),
#  ('ST544', 'L5719', 'R16'),
#  ('ST545', 'L12959', 'R11'),
#  ('ST546', 'L3744', 'R7'),
#  ('ST547', 'L7864', 'R3'),
#  ('ST548', 'L5048', 'R8'),
#  ('ST549', 'L16160', 'R8'),
#  ('ST55', 'L11480', 'R1'),
#  ('ST550', 'L10902', 'R9'),
#  ('ST551', 'L13179', 'R12'),
#  ('ST552', 'L1440', 'R15'),
#  ('ST553', 'L12609', 'R16'),
#  ('ST554', 'L5249', 'R1'),
#  ('ST555', 'L3975', 'R1'),
#  ('ST556', 'L4634', 'R1'),
#  ('ST557', 'L7262', 'R13'),
#  ('ST558', 'L3180', 'R16'),
#  ('ST559', 'L9988', 'R16'),
#  ('ST56', 'L11480', 'R5'),
#  ('ST560', 'L339', 'R15'),
#  ('ST561', 'L12450', 'R3'),
#  ('ST562', 'L12448', 'R16'),
#  ('ST563', 'L8924', 'R11'),
#  ('ST564', 'L10518', 'R12'),
#  ('ST565', 'L1472', 'R1'),
#  ('ST566', 'L6800', 'R7'),
#  ('ST567', 'L13746', 'R3'),
#  ('ST568', 'L4268', 'R12'),
#  ('ST569', 'L16050', 'R9'),
#  ('ST57', 'L11495', 'R16'),
#  ('ST570', 'L3541', 'R16'),
#  ('ST571', 'L11483', 'R16'),
#  ('ST572', 'L14478', 'R12'),
#  ('ST573', 'L5659', 'R13'),
#  ('ST574', 'L9222', 'R4'),
#  ('ST575', 'L211', 'R9'),
#  ('ST576', 'L15642', 'R12'),
#  ('ST577', 'L7283', 'R3'),
#  ('ST578', 'L6083', 'R11'),
#  ('ST579', 'L15781', 'R3'),
#  ('ST58', 'L11495', 'R7'),
#  ('ST580', 'L8943', 'R1'),
#  ('ST581', 'L14056', 'R16'),
#  ('ST582', 'L14983', 'R9'),
#  ('ST583', 'L3731', 'R15'),
#  ('ST584', 'L7760', 'R8'),
#  ('ST585', 'L1541', 'R8'),
#  ('ST586', 'L11382', 'R9'),
#  ('ST587', 'L7354', 'R5'),
#  ('ST588', 'L15466', 'R1'),
#  ('ST589', 'L15706', 'R4'),
#  ('ST59', 'L11495', 'R1'),
#  ('ST590', 'L13286', 'R4'),
#  ('ST591', 'L17980', 'R4'),
#  ('ST592', 'L9952', 'R16'),
#  ('ST593', 'L15665', 'R12'),
#  ('ST594', 'L9741', 'R11'),
#  ('ST595', 'L4529', 'R13'),
#  ('ST596', 'L13233', 'R11'),
#  ('ST597', 'L7622', 'R1'),
#  ('ST598', 'L11312', 'R16'),
#  ('ST599', 'L16194', 'R16'),
#  ('ST6', 'L9532', 'R10'),
#  ('ST60', 'L11495', 'R5'),
#  ('ST600', 'L18190', 'R12'),
#  ('ST601', 'L18071', 'R12'),
#  ('ST602', 'L17554', 'R15'),
#  ('ST603', 'L15892', 'R1'),
#  ('ST604', 'L16580', 'R13'),
#  ('ST605', 'L11333', 'R4'),
#  ('ST606', 'L14409', 'R12'),
#  ('ST607', 'L15014', 'R15'),
#  ('ST608', 'L5595', 'R12'),
#  ('ST609', 'L3603', 'R8'),
#  ('ST61', 'L1734', 'R16'),
#  ('ST610', 'L949', 'R9'),
#  ('ST611', 'L3444', 'R3'),
#  ('ST612', 'L5670', 'R15'),
#  ('ST613', 'L16029', 'R11'),
#  ('ST614', 'L3351', 'R3'),
#  ('ST615', 'L14271', 'R11'),
#  ('ST616', 'L6075', 'R16'),
#  ('ST617', 'L16936', 'R5'),
#  ('ST618', 'L9275', 'R4'),
#  ('ST619', 'L4289', 'R3'),
#  ('ST62', 'L1734', 'R7'),
#  ('ST620', 'L7099', 'R8'),
#  ('ST621', 'L2250', 'R4'),
#  ('ST622', 'L2657', 'R13'),
#  ('ST623', 'L16355', 'R8'),
#  ('ST624', 'L11855', 'R5'),
#  ('ST625', 'L3892', 'R5'),
#  ('ST626', 'L8033', 'R11'),
#  ('ST627', 'L1157', 'R8'),
#  ('ST628', 'L3179', 'R1'),
#  ('ST629', 'L15389', 'R9'),
#  ('ST63', 'L1734', 'R3'),
#  ('ST630', 'L2805', 'R8'),
#  ('ST631', 'L5715', 'R3'),
#  ('ST632', 'L16015', 'R11'),
#  ('ST633', 'L16282', 'R15'),
#  ('ST634', 'L48', 'R11'),
#  ('ST635', 'L11766', 'R1'),
#  ('ST636', 'L17835', 'R13'),
#  ('ST637', 'L12525', 'R16'),
#  ('ST638', 'L13424', 'R15'),
#  ('ST639', 'L2579', 'R7'),
#  ('ST64', 'L1734', 'R13'),
#  ('ST640', 'L5905', 'R16'),
#  ('ST641', 'L4043', 'R13'),
#  ('ST642', 'L6023', 'R8'),
#  ('ST643', 'L5570', 'R1'),
#  ('ST644', 'L1130', 'R3'),
#  ('ST645', 'L15180', 'R15'),
#  ('ST646', 'L14216', 'R7'),
#  ('ST647', 'L12276', 'R13'),
#  ('ST648', 'L15287', 'R8'),
#  ('ST649', 'L13654', 'R8'),
#  ('ST65', 'L1735', 'R13'),
#  ('ST650', 'L9086', 'R7'),
#  ('ST651', 'L16882', 'R9'),
#  ('ST652', 'L1357', 'R1'),
#  ('ST653', 'L5132', 'R15'),
#  ('ST654', 'L17978', 'R1'),
#  ('ST655', 'L6038', 'R9'),
#  ('ST656', 'L8643', 'R8'),
#  ('ST657', 'L7408', 'R11'),
#  ('ST658', 'L17565', 'R9'),
#  ('ST659', 'L1463', 'R15'),
#  ('ST66', 'L1735', 'R5'),
#  ('ST660', 'L8782', 'R7'),
#  ('ST661', 'L5977', 'R11'),
#  ('ST662', 'L4779', 'R16'),
#  ('ST663', 'L8245', 'R5'),
#  ('ST664', 'L371', 'R12'),
#  ('ST665', 'L662', 'R15'),
#  ('ST666', 'L17846', 'R3'),
#  ('ST667', 'L13803', 'R4'),
#  ('ST668', 'L10697', 'R15'),
#  ('ST669', 'L10480', 'R9'),
#  ('ST67', 'L1735', 'R14'),
#  ('ST670', 'L7522', 'R4'),
#  ('ST671', 'L11597', 'R1'),
#  ('ST672', 'L4360', 'R9'),
#  ('ST673', 'L14363', 'R12'),
#  ('ST674', 'L9833', 'R1'),
#  ('ST675', 'L5344', 'R15'),
#  ('ST676', 'L14213', 'R4'),
#  ('ST677', 'L9546', 'R9'),
#  ('ST678', 'L14265', 'R8'),
#  ('ST679', 'L12364', 'R5'),
#  ('ST68', 'L1735', 'R2'),
#  ('ST680', 'L13649', 'R7'),
#  ('ST681', 'L8324', 'R11'),
#  ('ST682', 'L8191', 'R11'),
#  ('ST683', 'L166', 'R15'),
#  ('ST684', 'L2779', 'R11'),
#  ('ST685', 'L2531', 'R5'),
#  ('ST686', 'L2547', 'R13'),
#  ('ST687', 'L15081', 'R1'),
#  ('ST688', 'L542', 'R11'),
#  ('ST689', 'L5367', 'R4'),
#  ('ST69', 'L1736', 'R2'),
#  ('ST690', 'L11166', 'R1'),
#  ('ST691', 'L2865', 'R15'),
#  ('ST692', 'L4599', 'R12'),
#  ('ST693', 'L10208', 'R8'),
#  ('ST694', 'L12045', 'R8'),
#  ('ST695', 'L3205', 'R4'),
#  ('ST696', 'L7228', 'R4'),
#  ('ST697', 'L8099', 'R9'),
#  ('ST698', 'L13613', 'R11'),
#  ('ST699', 'L16867', 'R9'),
#  ('ST7', 'L9532', 'R14'),
#  ('ST70', 'L1736', 'R6'),
#  ('ST700', 'L17937', 'R16'),
#  ('ST701', 'L6776', 'R11'),
#  ('ST702', 'L9535', 'R15'),
#  ('ST703', 'L5003', 'R15'),
#  ('ST704', 'L2446', 'R3'),
#  ('ST705', 'L15240', 'R11'),
#  ('ST706', 'L13511', 'R11'),
#  ('ST707', 'L913', 'R1'),
#  ('ST708', 'L15823', 'R7'),
#  ('ST709', 'L17432', 'R15'),
#  ('ST71', 'L1736', 'R10'),
#  ('ST710', 'L12483', 'R4'),
#  ('ST711', 'L11495', 'R4'),
#  ('ST712', 'L7463', 'R3'),
#  ('ST713', 'L3201', 'R15'),
#  ('ST714', 'L13162', 'R16'),
#  ('ST715', 'L16976', 'R16'),
#  ('ST716', 'L4906', 'R8'),
#  ('ST717', 'L17835', 'R13'),
#  ('ST718', 'L9900', 'R16'),
#  ('ST719', 'L72', 'R11'),
#  ('ST72', 'L1736', 'R14'),
#  ('ST720', 'L13419', 'R15'),
#  ('ST721', 'L8211', 'R13'),
#  ('ST722', 'L5318', 'R15'),
#  ('ST723', 'L10472', 'R13'),
#  ('ST724', 'L17256', 'R16'),
#  ('ST725', 'L8500', 'R8'),
#  ('ST726', 'L6181', 'R3'),
#  ('ST727', 'L10326', 'R3'),
#  ('ST728', 'L135', 'R12'),
#  ('ST729', 'L14203', 'R12'),
#  ('ST73', 'L1737', 'R6'),
#  ('ST730', 'L6162', 'R7'),
#  ('ST731', 'L9484', 'R15'),
#  ('ST732', 'L4090', 'R8'),
#  ('ST733', 'L16296', 'R11'),
#  ('ST734', 'L11999', 'R11'),
#  ('ST735', 'L17625', 'R1'),
#  ('ST736', 'L2285', 'R9'),
#  ('ST737', 'L10339', 'R12'),
#  ('ST738', 'L313', 'R12'),
#  ('ST739', 'L6318', 'R15'),
#  ('ST74', 'L1737', 'R10'),
#  ('ST740', 'L2020', 'R3'),
#  ('ST741', 'L16334', 'R9'),
#  ('ST742', 'L8484', 'R4'),
#  ('ST743', 'L15400', 'R8'),
#  ('ST744', 'L16606', 'R11'),
#  ('ST745', 'L17473', 'R4'),
#  ('ST746', 'L1929', 'R3'),
#  ('ST747', 'L11430', 'R16'),
#  ('ST748', 'L10426', 'R13'),
#  ('ST749', 'L10131', 'R3'),
#  ('ST75', 'L1737', 'R14'),
#  ('ST750', 'L5241', 'R7'),
#  ('ST751', 'L7233', 'R15'),
#  ('ST752', 'L1685', 'R9'),
#  ('ST753', 'L10909', 'R11'),
#  ('ST754', 'L15533', 'R4'),
#  ('ST755', 'L603', 'R9'),
#  ('ST756', 'L3943', 'R1'),
#  ('ST757', 'L2038', 'R15'),
#  ('ST758', 'L14012', 'R9'),
#  ('ST759', 'L6424', 'R3'),
#  ('ST76', 'L1737', 'R2'),
#  ('ST760', 'L4114', 'R9'),
#  ('ST761', 'L17939', 'R15'),
#  ('ST762', 'L15456', 'R8'),
#  ('ST763', 'L4606', 'R5'),
#  ('ST764', 'L11098', 'R16'),
#  ('ST765', 'L8343', 'R15'),
#  ('ST766', 'L11385', 'R15'),
#  ('ST767', 'L14376', 'R5'),
#  ('ST768', 'L431', 'R8'),
#  ('ST769', 'L14439', 'R13'),
#  ('ST77', 'L1738', 'R2'),
#  ('ST770', 'L15276', 'R4'),
#  ('ST771', 'L31', 'R4'),
#  ('ST772', 'L5508', 'R4'),
#  ('ST773', 'L6512', 'R15'),
#  ('ST774', 'L3515', 'R5'),
#  ('ST775', 'L1000', 'R15'),
#  ('ST776', 'L12295', 'R7'),
#  ('ST777', 'L7161', 'R12'),
#  ('ST778', 'L2234', 'R12'),
#  ('ST779', 'L9219', 'R15'),
#  ('ST78', 'L1738', 'R6'),
#  ('ST780', 'L9506', 'R13'),
#  ('ST781', 'L13012', 'R15'),
#  ('ST782', 'L12962', 'R3'),
#  ('ST783', 'L17511', 'R7'),
#  ('ST784', 'L6210', 'R11'),
#  ('ST785', 'L2362', 'R11'),
#  ('ST786', 'L7754', 'R12'),
#  ('ST787', 'L16478', 'R5'),
#  ('ST788', 'L4953', 'R7'),
#  ('ST789', 'L14449', 'R5'),
#  ('ST79', 'L1738', 'R10'),
#  ('ST790', 'L6055', 'R3'),
#  ('ST791', 'L126', 'R8'),
#  ('ST792', 'L12331', 'R7'),
#  ('ST793', 'L16819', 'R1'),
#  ('ST794', 'L3899', 'R12'),
#  ('ST795', 'L12372', 'R5'),
#  ('ST796', 'L3873', 'R8'),
#  ('ST797', 'L1977', 'R9'),
#  ('ST798', 'L13364', 'R15'),
#  ('ST799', 'L16087', 'R13'),
#  ('ST8', 'L9532', 'R2'),
#  ('ST80', 'L1738', 'R14'),
#  ('ST800', 'L492', 'R16'),
#  ('ST801', 'L17981', 'R15'),
#  ('ST802', 'L16249', 'R8'),
#  ('ST803', 'L6494', 'R16'),
#  ('ST804', 'L10695', 'R4'),
#  ('ST805', 'L10588', 'R7'),
#  ('ST806', 'L16239', 'R13'),
#  ('ST807', 'L12823', 'R12'),
#  ('ST808', 'L12310', 'R3'),
#  ('ST809', 'L11738', 'R7'),
#  ('ST81', 'L1940', 'R6'),
#  ('ST810', 'L9603', 'R5'),
#  ('ST811', 'L9070', 'R12'),
#  ('ST812', 'L4866', 'R7'),
#  ('ST813', 'L1741', 'R8'),
#  ('ST814', 'L4005', 'R4'),
#  ('ST815', 'L12297', 'R11'),
#  ('ST816', 'L6336', 'R5'),
#  ('ST817', 'L16685', 'R5'),
#  ('ST818', 'L8794', 'R1'),
#  ('ST819', 'L8017', 'R11'),
#  ('ST82', 'L1940', 'R10'),
#  ('ST820', 'L15371', 'R5'),
#  ('ST821', 'L10701', 'R4'),
#  ('ST822', 'L13142', 'R9'),
#  ('ST823', 'L11879', 'R11'),
#  ('ST824', 'L11491', 'R4'),
#  ('ST825', 'L9861', 'R13'),
#  ('ST826', 'L3212', 'R3'),
#  ('ST827', 'L10190', 'R12'),
#  ('ST828', 'L4380', 'R4'),
#  ('ST829', 'L5551', 'R4'),
#  ('ST83', 'L1940', 'R14'),
#  ('ST830', 'L12864', 'R5'),
#  ('ST831', 'L5134', 'R16'),
#  ('ST832', 'L16393', 'R5'),
#  ('ST833', 'L4448', 'R5'),
#  ('ST834', 'L4494', 'R13'),
#  ('ST835', 'L3945', 'R9'),
#  ('ST836', 'L12255', 'R1'),
#  ('ST837', 'L1488', 'R5'),
#  ('ST838', 'L15458', 'R16'),
#  ('ST839', 'L3695', 'R4'),
#  ('ST84', 'L1940', 'R2'),
#  ('ST840', 'L4619', 'R3'),
#  ('ST841', 'L8822', 'R13'),
#  ('ST842', 'L2666', 'R11'),
#  ('ST843', 'L316', 'R4'),
#  ('ST844', 'L15207', 'R16'),
#  ('ST845', 'L6869', 'R13'),
#  ('ST846', 'L17072', 'R3'),
#  ('ST847', 'L15837', 'R5'),
#  ('ST848', 'L6470', 'R9'),
#  ('ST849', 'L16053', 'R4'),
#  ('ST85', 'L1941', 'R6'),
#  ('ST850', 'L12519', 'R7'),
#  ('ST851', 'L9128', 'R12'),
#  ('ST852', 'L1220', 'R16'),
#  ('ST853', 'L1160', 'R7'),
#  ('ST854', 'L3999', 'R11'),
#  ('ST855', 'L18097', 'R9'),
#  ('ST856', 'L10034', 'R8'),
#  ('ST857', 'L17676', 'R11'),
#  ('ST858', 'L3001', 'R1'),
#  ('ST859', 'L17003', 'R4'),
#  ('ST86', 'L1941', 'R10'),
#  ('ST860', 'L2504', 'R16'),
#  ('ST861', 'L10459', 'R13'),
#  ('ST862', 'L4581', 'R4'),
#  ('ST863', 'L10643', 'R7'),
#  ('ST864', 'L12271', 'R16'),
#  ('ST865', 'L11164', 'R4'),
#  ('ST866', 'L886', 'R8'),
#  ('ST867', 'L13001', 'R12'),
#  ('ST868', 'L8053', 'R5'),
#  ('ST869', 'L2622', 'R15'),
#  ('ST87', 'L1941', 'R14'),
#  ('ST870', 'L1424', 'R16'),
#  ('ST871', 'L15551', 'R4'),
#  ('ST872', 'L17248', 'R5'),
#  ('ST873', 'L3368', 'R13'),
#  ('ST874', 'L14532', 'R15'),
#  ('ST875', 'L12711', 'R9'),
#  ('ST876', 'L11056', 'R15'),
#  ('ST877', 'L18082', 'R11'),
#  ('ST878', 'L7506', 'R8'),
#  ('ST879', 'L12930', 'R3'),
#  ('ST88', 'L1941', 'R2'),
#  ('ST880', 'L17975', 'R8'),
#  ('ST881', 'L8445', 'R11'),
#  ('ST882', 'L12085', 'R4'),
#  ('ST883', 'L7932', 'R3'),
#  ('ST884', 'L2278', 'R7'),
#  ('ST885', 'L1897', 'R15'),
#  ('ST886', 'L5774', 'R7'),
#  ('ST887', 'L13872', 'R15'),
#  ('ST888', 'L3810', 'R13'),
#  ('ST889', 'L3282', 'R12'),
#  ('ST89', 'L1942', 'R6'),
#  ('ST890', 'L2385', 'R11'),
#  ('ST891', 'L14432', 'R9'),
#  ('ST892', 'L17506', 'R5'),
#  ('ST893', 'L17394', 'R13'),
#  ('ST894', 'L7450', 'R3'),
#  ('ST895', 'L12348', 'R11'),
#  ('ST896', 'L1184', 'R3'),
#  ('ST897', 'L774', 'R11'),
#  ('ST898', 'L4957', 'R7'),
#  ('ST899', 'L7050', 'R4'),
#  ('ST9', 'L9533', 'R2'),
#  ('ST90', 'L1942', 'R10'),
#  ('ST900', 'L1243', 'R13'),
#  ('ST901', 'L6365', 'R5'),
#  ('ST902', 'L11794', 'R4'),
#  ('ST903', 'L16308', 'R7'),
#  ('ST904', 'L5537', 'R11'),
#  ('ST905', 'L6707', 'R7'),
#  ('ST906', 'L2809', 'R15'),
#  ('ST907', 'L8880', 'R11'),
#  ('ST908', 'L13952', 'R3'),
#  ('ST909', 'L487', 'R9'),
#  ('ST91', 'L1942', 'R14'),
#  ('ST910', 'L3342', 'R9'),
#  ('ST911', 'L11093', 'R13'),
#  ('ST912', 'L13267', 'R9'),
#  ('ST913', 'L13872', 'R1'),
#  ('ST914', 'L3185', 'R15'),
#  ('ST915', 'L12127', 'R7'),
#  ('ST916', 'L8335', 'R3'),
#  ('ST917', 'L114', 'R9'),
#  ('ST918', 'L6958', 'R7'),
#  ('ST919', 'L7747', 'R16'),
#  ('ST92', 'L1942', 'R2'),
#  ('ST920', 'L347', 'R15'),
#  ('ST921', 'L8409', 'R1'),
#  ('ST922', 'L14484', 'R13'),
#  ('ST923', 'L1386', 'R9'),
#  ('ST924', 'L4175', 'R16'),
#  ('ST925', 'L3069', 'R12'),
#  ('ST926', 'L11972', 'R15'),
#  ('ST927', 'L7612', 'R7'),
#  ('ST928', 'L16660', 'R3'),
#  ('ST929', 'L14897', 'R16'),
#  ('ST93', 'L1943', 'R2'),
#  ('ST930', 'L594', 'R8'),
#  ('ST931', 'L264', 'R16'),
#  ('ST932', 'L16925', 'R8'),
#  ('ST933', 'L6987', 'R13'),
#  ('ST934', 'L489', 'R8'),
#  ('ST935', 'L2690', 'R13'),
#  ('ST936', 'L1273', 'R12'),
#  ('ST937', 'L1332', 'R3'),
#  ('ST938', 'L18035', 'R3'),
#  ('ST939', 'L1657', 'R7'),
#  ('ST94', 'L1943', 'R6'),
#  ('ST940', 'L13909', 'R13'),
#  ('ST941', 'L16975', 'R11'),
#  ('ST942', 'L5956', 'R3'),
#  ('ST943', 'L10608', 'R1'),
#  ('ST944', 'L4211', 'R12'),
#  ('ST945', 'L944', 'R13'),
#  ('ST946', 'L4053', 'R12'),
#  ('ST947', 'L9004', 'R5'),
#  ('ST948', 'L9359', 'R1'),
#  ('ST949', 'L5131', 'R11'),
#  ('ST95', 'L1943', 'R10'),
#  ('ST950', 'L17798', 'R15'),
#  ('ST951', 'L8120', 'R5'),
#  ('ST952', 'L14882', 'R12'),
#  ('ST953', 'L8822', 'R1'),
#  ('ST954', 'L16524', 'R11'),
#  ('ST955', 'L13034', 'R8'),
#  ('ST956', 'L16457', 'R7'),
#  ('ST957', 'L9538', 'R1'),
#  ('ST958', 'L16343', 'R5'),
#  ('ST959', 'L7228', 'R8'),
#  ('ST96', 'L1943', 'R14'),
#  ('ST960', 'L10200', 'R13'),
#  ('ST961', 'L13150', 'R15'),
#  ('ST962', 'L12097', 'R8'),
#  ('ST963', 'L10191', 'R16'),
#  ('ST964', 'L9680', 'R3'),
#  ('ST965', 'L8952', 'R13'),
#  ('ST966', 'L10259', 'R16'),
#  ('ST967', 'L5092', 'R13'),
#  ('ST968', 'L6367', 'R4'),
#  ('ST969', 'L7621', 'R8'),
#  ('ST97', 'L1944', 'R6'),
#  ('ST970', 'L10365', 'R5'),
#  ('ST971', 'L11201', 'R7'),
#  ('ST972', 'L12067', 'R5'),
#  ('ST973', 'L10079', 'R8'),
#  ('ST974', 'L16797', 'R13'),
#  ('ST975', 'L17440', 'R1'),
#  ('ST976', 'L2053', 'R15'),
#  ('ST977', 'L9406', 'R12'),
#  ('ST978', 'L15211', 'R4'),
#  ('ST979', 'L1351', 'R9'),
#  ('ST98', 'L1944', 'R10'),
#  ('ST980', 'L8419', 'R3'),
#  ('ST981', 'L16626', 'R15'),
#  ('ST982', 'L7808', 'R12'),
#  ('ST983', 'L14960', 'R5'),
#  ('ST984', 'L15766', 'R11'),
#  ('ST985', 'L12806', 'R5'),
#  ('ST986', 'L12137', 'R15'),
#  ('ST987', 'L10323', 'R3'),
#  ('ST988', 'L298', 'R8'),
#  ('ST989', 'L85', 'R9'),
#  ('ST99', 'L1944', 'R14'),
#  ('ST990', 'L2983', 'R12'),
#  ('ST991', 'L7592', 'R3'),
#  ('ST992', 'L2787', 'R13'),
#  ('ST993', 'L1528', 'R15'),
#  ('ST994', 'L13653', 'R7'),
#  ('ST995', 'L5458', 'R4'),
#  ('ST996', 'L10771', 'R4'),
#  ('ST997', 'L11671', 'R12'),
#  ('ST998', 'L17570', 'R1'),
#  ('ST999', 'L9573', 'R8')]

# %% [markdown]
# #### What information is available for Watershed's 244 properties?

# %%
# %%sql
# SELECT w.ws_property_id, w.current_monthly_rent, w.property_type, p.apt_house, p.num_bedrooms, p.kitchen, p.shared, w.location,
# l.city, l.state, l.zipcode
# FROM watershed_property_info w, property_type p, location l
# WHERE w.property_type=p.property_type_id AND w.location=l.location_id;
# Out:
# 244 rows affected.
# [('W1', 1060, 'R6', 'apartment', '2', 'Y', 'N', 'L9531', 'Chapel Hill', 'NC', 27514),
#  ('W10', 1200, 'R6', 'apartment', '2', 'Y', 'N', 'L9533', 'Chapel Hill', 'NC', 27517),
#  ('W100', 3300, 'R2', 'apartment', '1', 'Y', 'N', 'L1944', 'San Francisco', 'CA', 94129),
#  ('W101', 1400, 'R2', 'apartment', '1', 'Y', 'N', 'L15257', 'Austin', 'TX', 78702),
#  ('W102', 2000, 'R6', 'apartment', '2', 'Y', 'N', 'L15257', 'Austin', 'TX', 78702),
#  ('W103', 1600, 'R10', 'house', '1', 'Y', 'N', 'L15257', 'Austin', 'TX', 78702),
#  ('W104', 2800, 'R14', 'house', '2', 'Y', 'N', 'L15257', 'Austin', 'TX', 78702),
#  ('W105', 1100, 'R2', 'apartment', '1', 'Y', 'N', 'L15260', 'Austin', 'TX', 78705),
#  ('W106', 1900, 'R6', 'apartment', '2', 'Y', 'N', 'L15260', 'Austin', 'TX', 78705),
#  ('W107', 1800, 'R10', 'house', '1', 'Y', 'N', 'L15260', 'Austin', 'TX', 78705),
#  ('W108', 3200, 'R14', 'house', '2', 'Y', 'N', 'L15260', 'Austin', 'TX', 78705),
#  ('W109', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'L15264', 'Austin', 'TX', 78723),
#  ('W11', 1000, 'R10', 'house', '1', 'Y', 'N', 'L9533', 'Chapel Hill', 'NC', 27517),
#  ('W110', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'L15264', 'Austin', 'TX', 78723),
#  ('W111', 1200, 'R10', 'house', '1', 'Y', 'N', 'L15264', 'Austin', 'TX', 78723),
#  ('W112', 1600, 'R14', 'house', '2', 'Y', 'N', 'L15264', 'Austin', 'TX', 78723),
#  ('W113', 800, 'R2', 'apartment', '1', 'Y', 'N', 'L15278', 'Austin', 'TX', 78744),
#  ('W114', 1200, 'R6', 'apartment', '2', 'Y', 'N', 'L15278', 'Austin', 'TX', 78744),
#  ('W115', 900, 'R10', 'house', '1', 'Y', 'N', 'L15278', 'Austin', 'TX', 78744),
#  ('W116', 1100, 'R14', 'house', '2', 'Y', 'N', 'L15278', 'Austin', 'TX', 78744),
#  ('W117', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'L15280', 'Austin', 'TX', 78746),
#  ('W118', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'L15280', 'Austin', 'TX', 78746),
#  ('W119', 1500, 'R10', 'house', '1', 'Y', 'N', 'L15280', 'Austin', 'TX', 78746),
#  ('W12', 1300, 'R14', 'house', '2', 'Y', 'N', 'L9533', 'Chapel Hill', 'NC', 27517),
#  ('W120', 1600, 'R14', 'house', '2', 'Y', 'N', 'L15280', 'Austin', 'TX', 78746),
#  ('W121', 600, 'R2', 'apartment', '1', 'Y', 'N', 'L463', 'Bentonville', 'AR', 72712),
#  ('W122', 800, 'R6', 'apartment', '2', 'Y', 'N', 'L463', 'Bentonville', 'AR', 72712),
#  ('W123', 700, 'R10', 'house', '1', 'Y', 'N', 'L463', 'Bentonville', 'AR', 72712),
#  ('W124', 1000, 'R14', 'house', '2', 'Y', 'N', 'L463', 'Bentonville', 'AR', 72712),
#  ('W125', 700, 'R2', 'apartment', '1', 'Y', 'N', 'L464', 'Bentonville', 'AR', 72719),
#  ('W126', 900, 'R6', 'apartment', '2', 'Y', 'N', 'L464', 'Bentonville', 'AR', 72719),
#  ('W127', 1000, 'R10', 'house', '1', 'Y', 'N', 'L464', 'Bentonville', 'AR', 72719),
#  ('W128', 1200, 'R14', 'house', '2', 'Y', 'N', 'L464', 'Bentonville', 'AR', 72719),
#  ('W129', 1200, 'R2', 'apartment', '1', 'Y', 'N', 'L2314', 'Denver', 'CO', 80204),
#  ('W13', 920, 'R6', 'apartment', '2', 'Y', 'N', 'L9534', 'Chapel Hill', 'NC', 27707),
#  ('W130', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'L2314', 'Denver', 'CO', 80204),
#  ('W131', 1100, 'R10', 'house', '1', 'Y', 'N', 'L2314', 'Denver', 'CO', 80204),
#  ('W132', 1200, 'R14', 'house', '2', 'Y', 'N', 'L2314', 'Denver', 'CO', 80204),
#  ('W133', 1300, 'R2', 'apartment', '1', 'Y', 'N', 'L2318', 'Denver', 'CO', 80209),
#  ('W134', 1700, 'R6', 'apartment', '2', 'Y', 'N', 'L2318', 'Denver', 'CO', 80209),
#  ('W135', 1200, 'R10', 'house', '1', 'Y', 'N', 'L2318', 'Denver', 'CO', 80209),
#  ('W136', 1900, 'R14', 'house', '2', 'Y', 'N', 'L2318', 'Denver', 'CO', 80209),
#  ('W137', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'L2323', 'Denver', 'CO', 80218),
#  ('W138', 1500, 'R6', 'apartment', '2', 'Y', 'N', 'L2323', 'Denver', 'CO', 80218),
#  ('W139', 1300, 'R10', 'house', '1', 'Y', 'N', 'L2323', 'Denver', 'CO', 80218),
#  ('W14', 850, 'R10', 'house', '1', 'Y', 'N', 'L9534', 'Chapel Hill', 'NC', 27707),
#  ('W140', 1800, 'R14', 'house', '2', 'Y', 'N', 'L2323', 'Denver', 'CO', 80218),
#  ('W141', 1100, 'R2', 'apartment', '1', 'Y', 'N', 'L2325', 'Denver', 'CO', 80220),
#  ('W142', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'L2325', 'Denver', 'CO', 80220),
#  ('W143', 1300, 'R10', 'house', '1', 'Y', 'N', 'L2325', 'Denver', 'CO', 80220),
#  ('W144', 1900, 'R14', 'house', '2', 'Y', 'N', 'L2325', 'Denver', 'CO', 80220),
#  ('W145', 900, 'R2', 'apartment', '1', 'Y', 'N', 'L2338', 'Denver', 'CO', 80249),
#  ('W146', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'L2338', 'Denver', 'CO', 80249),
#  ('W147', 1400, 'R10', 'house', '1', 'Y', 'N', 'L2338', 'Denver', 'CO', 80249),
#  ('W148', 1700, 'R14', 'house', '2', 'Y', 'N', 'L2338', 'Denver', 'CO', 80249),
#  ('W149', 800, 'R2', 'apartment', '1', 'Y', 'N', 'L3244', 'Miami', 'FL', 33122),
#  ('W15', 900, 'R14', 'house', '2', 'Y', 'N', 'L9534', 'Chapel Hill', 'NC', 27707),
#  ('W150', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'L3244', 'Miami', 'FL', 33122),
#  ('W151', 1400, 'R10', 'house', '1', 'Y', 'N', 'L3244', 'Miami', 'FL', 33122),
#  ('W152', 1900, 'R14', 'house', '2', 'Y', 'N', 'L3244', 'Miami', 'FL', 33122),
#  ('W153', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'L3256', 'Miami', 'FL', 33137),
#  ('W154', 2400, 'R6', 'apartment', '2', 'Y', 'N', 'L3256', 'Miami', 'FL', 33137),
#  ('W155', 2100, 'R10', 'house', '1', 'Y', 'N', 'L3256', 'Miami', 'FL', 33137),
#  ('W156', 3200, 'R14', 'house', '2', 'Y', 'N', 'L3256', 'Miami', 'FL', 33137),
#  ('W157', 1300, 'R2', 'apartment', '1', 'Y', 'N', 'L3261', 'Miami', 'FL', 33146),
#  ('W158', 1700, 'R6', 'apartment', '2', 'Y', 'N', 'L3261', 'Miami', 'FL', 33146),
#  ('W159', 1400, 'R10', 'house', '1', 'Y', 'N', 'L3261', 'Miami', 'FL', 33146),
#  ('W16', 750, 'R2', 'apartment', '1', 'Y', 'N', 'L9534', 'Chapel Hill', 'NC', 27707),
#  ('W160', 1900, 'R14', 'house', '2', 'Y', 'N', 'L3261', 'Miami', 'FL', 33146),
#  ('W161', 1600, 'R2', 'apartment', '1', 'Y', 'N', 'L3262', 'Miami', 'FL', 33149),
#  ('W162', 2200, 'R6', 'apartment', '2', 'Y', 'N', 'L3262', 'Miami', 'FL', 33149),
#  ('W163', 1500, 'R10', 'house', '1', 'Y', 'N', 'L3262', 'Miami', 'FL', 33149),
#  ('W164', 2400, 'R14', 'house', '2', 'Y', 'N', 'L3262', 'Miami', 'FL', 33149),
#  ('W165', 1600, 'R2', 'apartment', '1', 'Y', 'N', 'L3264', 'Miami', 'FL', 33178),
#  ('W166', 1900, 'R6', 'apartment', '2', 'Y', 'N', 'L3264', 'Miami', 'FL', 33178),
#  ('W167', 1400, 'R10', 'house', '1', 'Y', 'N', 'L3264', 'Miami', 'FL', 33178),
#  ('W168', 2000, 'R14', 'house', '2', 'Y', 'N', 'L3264', 'Miami', 'FL', 33178),
#  ('W169', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'L10126', 'Omaha', 'NE', 68046),
#  ('W17', 2500, 'R6', 'apartment', '2', 'Y', 'N', 'L4761', 'Chicago', 'IL', 60607),
#  ('W170', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'L10126', 'Omaha', 'NE', 68046),
#  ('W171', 1300, 'R10', 'house', '1', 'Y', 'N', 'L10126', 'Omaha', 'NE', 68046),
#  ('W172', 1800, 'R14', 'house', '2', 'Y', 'N', 'L10126', 'Omaha', 'NE', 68046),
#  ('W173', 700, 'R2', 'apartment', '1', 'Y', 'N', 'L10130', 'Omaha', 'NE', 68106),
#  ('W174', 900, 'R6', 'apartment', '2', 'Y', 'N', 'L10130', 'Omaha', 'NE', 68106),
#  ('W175', 1000, 'R10', 'house', '1', 'Y', 'N', 'L10130', 'Omaha', 'NE', 68106),
#  ('W176', 1200, 'R14', 'house', '2', 'Y', 'N', 'L10130', 'Omaha', 'NE', 68106),
#  ('W177', 700, 'R2', 'apartment', '1', 'Y', 'N', 'L10133', 'Omaha', 'NE', 68110),
#  ('W178', 1000, 'R6', 'apartment', '2', 'Y', 'N', 'L10133', 'Omaha', 'NE', 68110),
#  ('W179', 800, 'R10', 'house', '1', 'Y', 'N', 'L10133', 'Omaha', 'NE', 68110),
#  ('W18', 2500, 'R10', 'house', '1', 'Y', 'N', 'L4761', 'Chicago', 'IL', 60607),
#  ('W180', 900, 'R14', 'house', '2', 'Y', 'N', 'L10133', 'Omaha', 'NE', 68110),
#  ('W181', 700, 'R2', 'apartment', '1', 'Y', 'N', 'L10136', 'Omaha', 'NE', 68114),
#  ('W182', 1000, 'R6', 'apartment', '2', 'Y', 'N', 'L10136', 'Omaha', 'NE', 68114),
#  ('W183', 900, 'R10', 'house', '1', 'Y', 'N', 'L10136', 'Omaha', 'NE', 68114),
#  ('W184', 1200, 'R14', 'house', '2', 'Y', 'N', 'L10136', 'Omaha', 'NE', 68114),
#  ('W185', 1100, 'R2', 'apartment', '1', 'Y', 'N', 'L1882', 'San Diego', 'CA', 91910),
#  ('W186', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'L1882', 'San Diego', 'CA', 91910),
#  ('W187', 1300, 'R10', 'house', '1', 'Y', 'N', 'L1882', 'San Diego', 'CA', 91910),
#  ('W188', 1900, 'R14', 'house', '2', 'Y', 'N', 'L1882', 'San Diego', 'CA', 91910),
#  ('W189', 900, 'R2', 'apartment', '1', 'Y', 'N', 'L1883', 'San Diego', 'CA', 91950),
#  ('W19', 2800, 'R14', 'house', '2', 'Y', 'N', 'L4761', 'Chicago', 'IL', 60607),
#  ('W190', 1100, 'R6', 'apartment', '2', 'Y', 'N', 'L1883', 'San Diego', 'CA', 91950),
#  ('W191', 1300, 'R10', 'house', '1', 'Y', 'N', 'L1883', 'San Diego', 'CA', 91950),
#  ('W192', 1600, 'R14', 'house', '2', 'Y', 'N', 'L1883', 'San Diego', 'CA', 91950),
#  ('W193', 1400, 'R2', 'apartment', '1', 'Y', 'N', 'L1887', 'San Diego', 'CA', 92102),
#  ('W194', 2000, 'R6', 'apartment', '2', 'Y', 'N', 'L1887', 'San Diego', 'CA', 92102),
#  ('W195', 1700, 'R10', 'house', '1', 'Y', 'N', 'L1887', 'San Diego', 'CA', 92102),
#  ('W196', 2500, 'R14', 'house', '2', 'Y', 'N', 'L1887', 'San Diego', 'CA', 92102),
#  ('W197', 1800, 'R2', 'apartment', '1', 'Y', 'N', 'L1902', 'San Diego', 'CA', 92118),
#  ('W198', 2600, 'R6', 'apartment', '2', 'Y', 'N', 'L1902', 'San Diego', 'CA', 92118),
#  ('W199', 2500, 'R10', 'house', '1', 'Y', 'N', 'L1902', 'San Diego', 'CA', 92118),
#  ('W2', 1500, 'R10', 'house', '1', 'Y', 'N', 'L9531', 'Chapel Hill', 'NC', 27514),
#  ('W20', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'L4761', 'Chicago', 'IL', 60607),
#  ('W200', 3600, 'R14', 'house', '2', 'Y', 'N', 'L1902', 'San Diego', 'CA', 92118),
#  ('W201', 1200, 'R2', 'apartment', '1', 'Y', 'N', 'L1916', 'San Diego', 'CA', 92154),
#  ('W202', 1600, 'R6', 'apartment', '2', 'Y', 'N', 'L1916', 'San Diego', 'CA', 92154),
#  ('W203', 1000, 'R10', 'house', '1', 'Y', 'N', 'L1916', 'San Diego', 'CA', 92154),
#  ('W204', 1500, 'R14', 'house', '2', 'Y', 'N', 'L1916', 'San Diego', 'CA', 92154),
#  ('W205', 750, 'R2', 'apartment', '1', 'Y', 'N', 'L12252', 'Columbus', 'OH', 43201),
#  ('W206', 1040, 'R6', 'apartment', '2', 'Y', 'N', 'L12252', 'Columbus', 'OH', 43201),
#  ('W207', 900, 'R10', 'house', '1', 'Y', 'N', 'L12252', 'Columbus', 'OH', 43201),
#  ('W208', 1400, 'R14', 'house', '2', 'Y', 'N', 'L12252', 'Columbus', 'OH', 43201),
#  ('W209', 825, 'R2', 'apartment', '1', 'Y', 'N', 'L12260', 'Columbus', 'OH', 43212),
#  ('W21', 2700, 'R6', 'apartment', '2', 'Y', 'N', 'L4765', 'Chicago', 'IL', 60611),
#  ('W210', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'L12260', 'Columbus', 'OH', 43212),
#  ('W211', 1000, 'R10', 'house', '1', 'Y', 'N', 'L12260', 'Columbus', 'OH', 43212),
#  ('W212', 1480, 'R14', 'house', '2', 'Y', 'N', 'L12260', 'Columbus', 'OH', 43212),
#  ('W213', 650, 'R2', 'apartment', '1', 'Y', 'N', 'L12264', 'Columbus', 'OH', 43222),
#  ('W214', 920, 'R6', 'apartment', '2', 'Y', 'N', 'L12264', 'Columbus', 'OH', 43222),
#  ('W215', 880, 'R10', 'house', '1', 'Y', 'N', 'L12264', 'Columbus', 'OH', 43222),
#  ('W216', 1200, 'R14', 'house', '2', 'Y', 'N', 'L12264', 'Columbus', 'OH', 43222),
#  ('W217', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'L16888', 'Richmond', 'VA', 23113),
#  ('W218', 1200, 'R6', 'apartment', '2', 'Y', 'N', 'L16888', 'Richmond', 'VA', 23113),
#  ('W219', 1400, 'R10', 'house', '1', 'Y', 'N', 'L16888', 'Richmond', 'VA', 23113),
#  ('W22', 2700, 'R10', 'house', '1', 'Y', 'N', 'L4765', 'Chicago', 'IL', 60611),
#  ('W220', 1600, 'R14', 'house', '2', 'Y', 'N', 'L16888', 'Richmond', 'VA', 23113),
#  ('W221', 1105, 'R2', 'apartment', '1', 'Y', 'N', 'L16887', 'Richmond', 'VA', 23060),
#  ('W222', 1665, 'R6', 'apartment', '2', 'Y', 'N', 'L16887', 'Richmond', 'VA', 23060),
#  ('W223', 1175, 'R10', 'house', '1', 'Y', 'N', 'L16887', 'Richmond', 'VA', 23060),
#  ('W224', 1725, 'R14', 'house', '2', 'Y', 'N', 'L16887', 'Richmond', 'VA', 23060),
#  ('W225', 709, 'R2', 'apartment', '1', 'Y', 'N', 'L16898', 'Richmond', 'VA', 23234),
#  ('W226', 869, 'R6', 'apartment', '2', 'Y', 'N', 'L16898', 'Richmond', 'VA', 23234),
#  ('W227', 925, 'R10', 'house', '1', 'Y', 'N', 'L16898', 'Richmond', 'VA', 23234),
#  ('W228', 1350, 'R14', 'house', '2', 'Y', 'N', 'L16898', 'Richmond', 'VA', 23234),
#  ('W229', 900, 'R2', 'apartment', '1', 'Y', 'N', 'L16890', 'Richmond', 'VA', 23220),
#  ('W23', 3200, 'R14', 'house', '2', 'Y', 'N', 'L4765', 'Chicago', 'IL', 60611),
#  ('W230', 1325, 'R6', 'apartment', '2', 'Y', 'N', 'L16890', 'Richmond', 'VA', 23220),
#  ('W231', 975, 'R10', 'house', '1', 'Y', 'N', 'L16890', 'Richmond', 'VA', 23220),
#  ('W232', 1550, 'R14', 'house', '2', 'Y', 'N', 'L16890', 'Richmond', 'VA', 23220),
#  ('W233', 1165, 'R2', 'apartment', '1', 'Y', 'N', 'L14416', 'Charleston', 'SC', 29438),
#  ('W234', 1625, 'R6', 'apartment', '2', 'Y', 'N', 'L14416', 'Charleston', 'SC', 29438),
#  ('W235', 1400, 'R10', 'house', '1', 'Y', 'N', 'L14416', 'Charleston', 'SC', 29438),
#  ('W236', 1995, 'R14', 'house', '2', 'Y', 'N', 'L14416', 'Charleston', 'SC', 29438),
#  ('W237', 760, 'R2', 'apartment', '1', 'Y', 'N', 'L14418', 'Charleston', 'SC', 29470),
#  ('W238', 965, 'R6', 'apartment', '2', 'Y', 'N', 'L14418', 'Charleston', 'SC', 29470),
#  ('W239', 1185, 'R10', 'house', '1', 'Y', 'N', 'L14418', 'Charleston', 'SC', 29470),
#  ('W24', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'L4765', 'Chicago', 'IL', 60611),
#  ('W240', 1340, 'R14', 'house', '2', 'Y', 'N', 'L14418', 'Charleston', 'SC', 29470),
#  ('W241', 1150, 'R2', 'apartment', '1', 'Y', 'N', 'L14419', 'Charleston', 'SC', 29487),
#  ('W242', 2000, 'R6', 'apartment', '2', 'Y', 'N', 'L14419', 'Charleston', 'SC', 29487),
#  ('W243', 1600, 'R10', 'house', '1', 'Y', 'N', 'L14419', 'Charleston', 'SC', 29487),
#  ('W244', 2150, 'R14', 'house', '2', 'Y', 'N', 'L14419', 'Charleston', 'SC', 29487),
#  ('W25', 1600, 'R2', 'apartment', '1', 'Y', 'N', 'L4770', 'Chicago', 'IL', 60616),
#  ('W26', 2100, 'R6', 'apartment', '2', 'Y', 'N', 'L4770', 'Chicago', 'IL', 60616),
#  ('W27', 1200, 'R10', 'house', '1', 'Y', 'N', 'L4770', 'Chicago', 'IL', 60616),
#  ('W28', 2100, 'R14', 'house', '2', 'Y', 'N', 'L4770', 'Chicago', 'IL', 60616),
#  ('W29', 2500, 'R6', 'apartment', '2', 'Y', 'N', 'L4794', 'Chicago', 'IL', 60642),
#  ('W3', 2000, 'R14', 'house', '2', 'Y', 'N', 'L9531', 'Chapel Hill', 'NC', 27514),
#  ('W30', 2500, 'R10', 'house', '1', 'Y', 'N', 'L4794', 'Chicago', 'IL', 60642),
#  ('W31', 2750, 'R14', 'house', '2', 'Y', 'N', 'L4794', 'Chicago', 'IL', 60642),
#  ('W32', 1800, 'R2', 'apartment', '1', 'Y', 'N', 'L4794', 'Chicago', 'IL', 60642),
#  ('W33', 3000, 'R6', 'apartment', '2', 'Y', 'N', 'L4804', 'Chicago', 'IL', 60654),
#  ('W34', 2000, 'R10', 'house', '1', 'Y', 'N', 'L4804', 'Chicago', 'IL', 60654),
#  ('W35', 2950, 'R14', 'house', '2', 'Y', 'N', 'L4804', 'Chicago', 'IL', 60654),
#  ('W36', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'L4804', 'Chicago', 'IL', 60654),
#  ('W37', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'L11419', 'New York', 'NY', 10002),
#  ('W38', 3200, 'R6', 'apartment', '2', 'Y', 'N', 'L11419', 'New York', 'NY', 10002),
#  ('W39', 4500, 'R6', 'apartment', '2', 'Y', 'N', 'L11421', 'New York', 'NY', 10004),
#  ('W4', 800, 'R2', 'apartment', '1', 'Y', 'N', 'L9531', 'Chapel Hill', 'NC', 27514),
#  ('W40', 4500, 'R10', 'house', '1', 'Y', 'N', 'L11421', 'New York', 'NY', 10004),
#  ('W41', 5500, 'R14', 'house', '2', 'Y', 'N', 'L11421', 'New York', 'NY', 10004),
#  ('W42', 3500, 'R2', 'apartment', '1', 'Y', 'N', 'L11421', 'New York', 'NY', 10004),
#  ('W43', 4000, 'R6', 'apartment', '2', 'Y', 'N', 'L11427', 'New York', 'NY', 10014),
#  ('W44', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'L11427', 'New York', 'NY', 10014),
#  ('W45', 5600, 'R6', 'apartment', '2', 'Y', 'N', 'L11431', 'New York', 'NY', 10019),
#  ('W46', 3200, 'R10', 'house', '1', 'Y', 'N', 'L11431', 'New York', 'NY', 10019),
#  ('W47', 3500, 'R14', 'house', '2', 'Y', 'N', 'L11431', 'New York', 'NY', 10019),
#  ('W48', 3400, 'R2', 'apartment', '1', 'Y', 'N', 'L11431', 'New York', 'NY', 10019),
#  ('W49', 4200, 'R6', 'apartment', '2', 'Y', 'N', 'L11434', 'New York', 'NY', 10023),
#  ('W5', 1100, 'R6', 'apartment', '2', 'Y', 'N', 'L9532', 'Chapel Hill', 'NC', 27516),
#  ('W50', 3000, 'R10', 'house', '1', 'Y', 'N', 'L11434', 'New York', 'NY', 10023),
#  ('W51', 3900, 'R14', 'house', '2', 'Y', 'N', 'L11434', 'New York', 'NY', 10023),
#  ('W52', 3600, 'R2', 'apartment', '1', 'Y', 'N', 'L11434', 'New York', 'NY', 10023),
#  ('W53', 3500, 'R6', 'apartment', '2', 'Y', 'N', 'L11480', 'New York', 'NY', 11101),
#  ('W54', 2500, 'R10', 'house', '1', 'Y', 'N', 'L11480', 'New York', 'NY', 11101),
#  ('W55', 3000, 'R14', 'house', '2', 'Y', 'N', 'L11480', 'New York', 'NY', 11101),
#  ('W56', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'L11480', 'New York', 'NY', 11101),
#  ('W57', 3900, 'R6', 'apartment', '2', 'Y', 'N', 'L11495', 'New York', 'NY', 11211),
#  ('W58', 2800, 'R10', 'house', '1', 'Y', 'N', 'L11495', 'New York', 'NY', 11211),
#  ('W59', 3500, 'R14', 'house', '2', 'Y', 'N', 'L11495', 'New York', 'NY', 11211),
#  ('W6', 900, 'R10', 'house', '1', 'Y', 'N', 'L9532', 'Chapel Hill', 'NC', 27516),
#  ('W60', 2600, 'R2', 'apartment', '1', 'Y', 'N', 'L11495', 'New York', 'NY', 11211),
#  ('W61', 2695, 'R6', 'apartment', '2', 'Y', 'N', 'L1734', 'Palo Alto', 'CA', 94025),
#  ('W62', 3000, 'R10', 'house', '1', 'Y', 'N', 'L1734', 'Palo Alto', 'CA', 94025),
#  ('W63', 4000, 'R14', 'house', '2', 'Y', 'N', 'L1734', 'Palo Alto', 'CA', 94025),
#  ('W64', 2295, 'R2', 'apartment', '1', 'Y', 'N', 'L1734', 'Palo Alto', 'CA', 94025),
#  ('W65', 3000, 'R6', 'apartment', '2', 'Y', 'N', 'L1735', 'Palo Alto', 'CA', 94301),
#  ('W66', 3300, 'R10', 'house', '1', 'Y', 'N', 'L1735', 'Palo Alto', 'CA', 94301),
#  ('W67', 4500, 'R14', 'house', '2', 'Y', 'N', 'L1735', 'Palo Alto', 'CA', 94301),
#  ('W68', 2700, 'R2', 'apartment', '1', 'Y', 'N', 'L1735', 'Palo Alto', 'CA', 94301),
#  ('W69', 2700, 'R2', 'apartment', '1', 'Y', 'N', 'L1736', 'Palo Alto', 'CA', 94303),
#  ('W7', 1100, 'R14', 'house', '2', 'Y', 'N', 'L9532', 'Chapel Hill', 'NC', 27516),
#  ('W70', 3000, 'R6', 'apartment', '2', 'Y', 'N', 'L1736', 'Palo Alto', 'CA', 94303),
#  ('W71', 4500, 'R10', 'house', '1', 'Y', 'N', 'L1736', 'Palo Alto', 'CA', 94303),
#  ('W72', 4900, 'R14', 'house', '2', 'Y', 'N', 'L1736', 'Palo Alto', 'CA', 94303),
#  ('W73', 3300, 'R6', 'apartment', '2', 'Y', 'N', 'L1737', 'Palo Alto', 'CA', 94305),
#  ('W74', 4500, 'R10', 'house', '1', 'Y', 'N', 'L1737', 'Palo Alto', 'CA', 94305),
#  ('W75', 4200, 'R14', 'house', '2', 'Y', 'N', 'L1737', 'Palo Alto', 'CA', 94305),
#  ('W76', 2500, 'R2', 'apartment', '1', 'Y', 'N', 'L1737', 'Palo Alto', 'CA', 94305),
#  ('W77', 2500, 'R2', 'apartment', '1', 'Y', 'N', 'L1738', 'Palo Alto', 'CA', 94306),
#  ('W78', 3300, 'R6', 'apartment', '2', 'Y', 'N', 'L1738', 'Palo Alto', 'CA', 94306),
#  ('W79', 4500, 'R10', 'house', '1', 'Y', 'N', 'L1738', 'Palo Alto', 'CA', 94306),
#  ('W8', 500, 'R2', 'apartment', '1', 'Y', 'N', 'L9532', 'Chapel Hill', 'NC', 27516),
#  ('W80', 4200, 'R14', 'house', '2', 'Y', 'N', 'L1738', 'Palo Alto', 'CA', 94306),
#  ('W81', 3600, 'R6', 'apartment', '2', 'Y', 'N', 'L1940', 'San Francisco', 'CA', 94103),
#  ('W82', 4000, 'R10', 'house', '1', 'Y', 'N', 'L1940', 'San Francisco', 'CA', 94103),
#  ('W83', 5500, 'R14', 'house', '2', 'Y', 'N', 'L1940', 'San Francisco', 'CA', 94103),
#  ('W84', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'L1940', 'San Francisco', 'CA', 94103),
#  ('W85', 4000, 'R6', 'apartment', '2', 'Y', 'N', 'L1941', 'San Francisco', 'CA', 94110),
#  ('W86', 4000, 'R10', 'house', '1', 'Y', 'N', 'L1941', 'San Francisco', 'CA', 94110),
#  ('W87', 5000, 'R14', 'house', '2', 'Y', 'N', 'L1941', 'San Francisco', 'CA', 94110),
#  ('W88', 3200, 'R2', 'apartment', '1', 'Y', 'N', 'L1941', 'San Francisco', 'CA', 94110),
#  ('W89', 3500, 'R6', 'apartment', '2', 'Y', 'N', 'L1942', 'San Francisco', 'CA', 94112),
#  ('W9', 965, 'R2', 'apartment', '1', 'Y', 'N', 'L9533', 'Chapel Hill', 'NC', 27517),
#  ('W90', 3200, 'R10', 'house', '1', 'Y', 'N', 'L1942', 'San Francisco', 'CA', 94112),
#  ('W91', 3500, 'R14', 'house', '2', 'Y', 'N', 'L1942', 'San Francisco', 'CA', 94112),
#  ('W92', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'L1942', 'San Francisco', 'CA', 94112),
#  ('W93', 2600, 'R2', 'apartment', '1', 'Y', 'N', 'L1943', 'San Francisco', 'CA', 94118),
#  ('W94', 4000, 'R6', 'apartment', '2', 'Y', 'N', 'L1943', 'San Francisco', 'CA', 94118),
#  ('W95', 4000, 'R10', 'house', '1', 'Y', 'N', 'L1943', 'San Francisco', 'CA', 94118),
#  ('W96', 5100, 'R14', 'house', '2', 'Y', 'N', 'L1943', 'San Francisco', 'CA', 94118),
#  ('W97', 5600, 'R6', 'apartment', '2', 'Y', 'N', 'L1944', 'San Francisco', 'CA', 94129),
#  ('W98', 5000, 'R10', 'house', '1', 'Y', 'N', 'L1944', 'San Francisco', 'CA', 94129),
#  ('W99', 6000, 'R14', 'house', '2', 'Y', 'N', 'L1944', 'San Francisco', 'CA', 94129)]

# %% [markdown]
# #### These properties are located in which distinct zip codes?

# %%
# %%sql
# SELECT DISTINCT l.zipcode
# FROM watershed_property_info w, location l
# WHERE w.location=l.location_id
# GROUP BY l.zipcode;
# Out:
# 62 rows affected.
# [(10002,),
#  (10004,),
#  (10014,),
#  (10019,),
#  (10023,),
#  (11101,),
#  (11211,),
#  (23060,),
#  (23113,),
#  (23220,),
#  (23234,),
#  (27514,),
#  (27516,),
#  (27517,),
#  (27707,),
#  (29438,),
#  (29470,),
#  (29487,),
#  (33122,),
#  (33137,),
#  (33146,),
#  (33149,),
#  (33178,),
#  (43201,),
#  (43212,),
#  (43222,),
#  (60607,),
#  (60611,),
#  (60616,),
#  (60642,),
#  (60654,),
#  (68046,),
#  (68106,),
#  (68110,),
#  (68114,),
#  (72712,),
#  (72719,),
#  (78702,),
#  (78705,),
#  (78723,),
#  (78744,),
#  (78746,),
#  (80204,),
#  (80209,),
#  (80218,),
#  (80220,),
#  (80249,),
#  (91910,),
#  (91950,),
#  (92102,),
#  (92118,),
#  (92154,),
#  (94025,),
#  (94103,),
#  (94110,),
#  (94112,),
#  (94118,),
#  (94129,),
#  (94301,),
#  (94303,),
#  (94305,),
#  (94306,)]

# %% [markdown]
# #### Calculate occupancy rates for the short-term property example data
# ##### Divide the number of days in 2015 that the property had been rented by the number of total days in 2015

# %%
# %%sql
# SELECT st_property, COUNT(rental_date)/365 AS Occupancy
# FROM st_rental_dates
# WHERE EXTRACT(year FROM rental_date)=2015
# GROUP BY st_property
# LIMIT 10;
# Out:
# 10 rows affected.
# [('ST1', Decimal('0.1616')),
#  ('ST10', Decimal('0.3479')),
#  ('ST100', Decimal('0.3973')),
#  ('ST1000', Decimal('0.9808')),
#  ('ST101', Decimal('0.3644')),
#  ('ST102', Decimal('0.4110')),
#  ('ST103', Decimal('0.4110')),
#  ('ST104', Decimal('0.5260')),
#  ('ST105', Decimal('0.4329')),
#  ('ST106', Decimal('0.6959'))]

# %% [markdown]
# #### These occupancy rates correspond to which locations and property types?

# %%
# %%sql
# SELECT sd.st_property, COUNT(sd.rental_date)/365 AS Occupancy, si.location, si.property_type
# FROM st_property_info si JOIN st_rental_dates sd
#   ON si.st_property_id=sd.st_property
# WHERE EXTRACT(year FROM rental_date)=2015
# GROUP BY st_property
# LIMIT 10;
# Out:
# 10 rows affected.
# [('ST1', Decimal('0.1616'), 'L9531', 'R6'),
#  ('ST10', Decimal('0.3479'), 'L9533', 'R6'),
#  ('ST100', Decimal('0.3973'), 'L1944', 'R2'),
#  ('ST1000', Decimal('0.9808'), 'L5957', 'R1'),
#  ('ST101', Decimal('0.3644'), 'L15257', 'R2'),
#  ('ST102', Decimal('0.4110'), 'L15257', 'R6'),
#  ('ST103', Decimal('0.4110'), 'L15257', 'R10'),
#  ('ST104', Decimal('0.5260'), 'L15257', 'R14'),
#  ('ST105', Decimal('0.4329'), 'L15260', 'R2'),
#  ('ST106', Decimal('0.6959'), 'L15260', 'R6')]

# %% [markdown]
# #### What are the sample nightly rent prices for these properties?

# %%
# %%sql
# SELECT i.st_property_id, p.sample_nightly_rent_price, i.location, i.property_type
# FROM st_property_info i JOIN st_rental_prices p
#   ON i.location=p.location
# GROUP BY st_property_id
# LIMIT 10;
# Out:
# 10 rows affected.
# [('ST1', 104, 'L9531', 'R6'),
#  ('ST10', 50, 'L9533', 'R6'),
#  ('ST100', 139, 'L1944', 'R2'),
#  ('ST101', 420, 'L15257', 'R2'),
#  ('ST102', 420, 'L15257', 'R6'),
#  ('ST103', 420, 'L15257', 'R10'),
#  ('ST104', 420, 'L15257', 'R14'),
#  ('ST105', 249, 'L15260', 'R2'),
#  ('ST106', 249, 'L15260', 'R6'),
#  ('ST107', 249, 'L15260', 'R10')]

# %% [markdown]
# #### What is the nightly rent price for short-term rental examples corresponding to Watershed's properties of the same location and property type?

# %%
# %%sql
# SELECT w.ws_property_id, w.location, w.property_type, sp.percentile_10th_price, sp.percentile_90th_price, sp.sample_nightly_rent_price
# FROM watershed_property_info w JOIN st_rental_prices sp
#   ON w.location=sp.location AND w.property_type=sp.property_type
# GROUP BY w.ws_property_id
# LIMIT 10;
# Out:
# 10 rows affected.
# [('W1', 'L9531', 'R6', 114, 153, 148),
#  ('W10', 'L9533', 'R6', 111, 149, 133),
#  ('W100', 'L1944', 'R2', 108, 610, 372),
#  ('W101', 'L15257', 'R2', 178, 533, 302),
#  ('W102', 'L15257', 'R6', 221, 617, 429),
#  ('W103', 'L15257', 'R10', 202, 646, 380),
#  ('W104', 'L15257', 'R14', 197, 639, 374),
#  ('W105', 'L15260', 'R2', 114, 477, 386),
#  ('W106', 'L15260', 'R6', 80, 583, 212),
#  ('W107', 'L15260', 'R10', 239, 1431, 969)]

# %% [markdown]
# #### Join the Watershed Property IDs with corresponding sample occupancy rates

# %%
# %%sql
# SELECT w.ws_property_id, w.location, w.property_type, Sample.Occupancy
# FROM watershed_property_info w LEFT JOIN (SELECT si.location, si.property_type, sd.st_property, COUNT(sd.rental_date)/365
#                                           AS Occupancy
#                                           FROM st_property_info si JOIN st_rental_dates sd
#                                             ON si.st_property_id=sd.st_property
#                                           WHERE EXTRACT(year FROM rental_date)=2015
#                                           GROUP BY st_property) AS Sample
#   ON w.location=Sample.location AND w.property_type=Sample.property_type
# GROUP BY w.ws_property_id
# LIMIT 10;
# Out:
# 10 rows affected.
# [('W1', 'L9531', 'R6', Decimal('0.1616')),
#  ('W10', 'L9533', 'R6', Decimal('0.3479')),
#  ('W100', 'L1944', 'R2', Decimal('0.3973')),
#  ('W101', 'L15257', 'R2', Decimal('0.3644')),
#  ('W102', 'L15257', 'R6', Decimal('0.4110')),
#  ('W103', 'L15257', 'R10', Decimal('0.4110')),
#  ('W104', 'L15257', 'R14', Decimal('0.5260')),
#  ('W105', 'L15260', 'R2', Decimal('0.4329')),
#  ('W106', 'L15260', 'R6', Decimal('0.6959')),
#  ('W107', 'L15260', 'R10', Decimal('0.1096'))]

# %% [markdown]
# #### Join the Watershed Property IDs with corresponding sample nightly rent prices

# %%
# %%sql
# SELECT w.ws_property_id, w.location, w.property_type, l.city, l.state, l.zipcode, p.apt_house, p.num_bedrooms, p.kitchen,
# p.shared, w.current_monthly_rent, sample_price.percentile_10th_price, sample_price.percentile_90th_price,
# sample_price.sample_nightly_rent_price
# FROM watershed_property_info w, location l, property_type p,
#     (SELECT w.ws_property_id, w.location, w.property_type,
#      sp.percentile_10th_price, sp.percentile_90th_price,
#      sp.sample_nightly_rent_price
#      FROM watershed_property_info w JOIN st_rental_prices sp
#        ON w.location=sp.location AND w.property_type=sp.property_type
#      GROUP BY w.ws_property_id) AS sample_price
# WHERE w.property_type=p.property_type_id AND w.location=l.location_id AND w.ws_property_id=sample_price.ws_property_id
# GROUP BY w.ws_property_id
# LIMIT 10;
# Out:
# 10 rows affected.
# [('W1', 'L9531', 'R6', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, 148),
#  ('W10', 'L9533', 'R6', 'Chapel Hill', 'NC', 27517, 'apartment', '2', 'Y', 'N', 1200, 111, 149, 133),
#  ('W100', 'L1944', 'R2', 'San Francisco', 'CA', 94129, 'apartment', '1', 'Y', 'N', 3300, 108, 610, 372),
#  ('W101', 'L15257', 'R2', 'Austin', 'TX', 78702, 'apartment', '1', 'Y', 'N', 1400, 178, 533, 302),
#  ('W102', 'L15257', 'R6', 'Austin', 'TX', 78702, 'apartment', '2', 'Y', 'N', 2000, 221, 617, 429),
#  ('W103', 'L15257', 'R10', 'Austin', 'TX', 78702, 'house', '1', 'Y', 'N', 1600, 202, 646, 380),
#  ('W104', 'L15257', 'R14', 'Austin', 'TX', 78702, 'house', '2', 'Y', 'N', 2800, 197, 639, 374),
#  ('W105', 'L15260', 'R2', 'Austin', 'TX', 78705, 'apartment', '1', 'Y', 'N', 1100, 114, 477, 386),
#  ('W106', 'L15260', 'R6', 'Austin', 'TX', 78705, 'apartment', '2', 'Y', 'N', 1900, 80, 583, 212),
#  ('W107', 'L15260', 'R10', 'Austin', 'TX', 78705, 'house', '1', 'Y', 'N', 1800, 239, 1431, 969)]

# %% [markdown]
# #### Join the above two queries

# %%
# %%sql
# SELECT w.ws_property_id, w.location, w.property_type, l.city, l.state, l.zipcode, p.apt_house, p.num_bedrooms, p.kitchen,
# p.shared, w.current_monthly_rent, sample_price.percentile_10th_price, sample_price.percentile_90th_price,
# sample_price.sample_nightly_rent_price, sample_dates.Occupancy
# FROM watershed_property_info w, location l, property_type p,
#     (SELECT w.ws_property_id, w.location, w.property_type,
#      sp.percentile_10th_price, sp.percentile_90th_price,
#      sp.sample_nightly_rent_price
#      FROM watershed_property_info w JOIN st_rental_prices sp
#        ON w.location=sp.location AND w.property_type=sp.property_type
#      GROUP BY w.ws_property_id) AS sample_price,
#     (SELECT w.ws_property_id, w.location, w.property_type, Sample.Occupancy
#      FROM watershed_property_info w LEFT JOIN (SELECT si.location, si.property_type, sd.st_property, COUNT(sd.rental_date)/365
#                                                AS Occupancy
#                                                FROM st_property_info si JOIN st_rental_dates sd
#                                                  ON si.st_property_id=sd.st_property
#                                                WHERE EXTRACT(year FROM rental_date)=2015
#                                                GROUP BY st_property) AS Sample
#        ON w.location=Sample.location AND w.property_type=Sample.property_type
#      GROUP BY w.ws_property_id) AS sample_dates
# WHERE w.property_type=p.property_type_id AND w.location=l.location_id AND w.ws_property_id=sample_price.ws_property_id AND
# w.ws_property_id=sample_dates.ws_property_id
# GROUP BY w.ws_property_id
# LIMIT 10;
# Out:
# 10 rows affected.
# [('W1', 'L9531', 'R6', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, 148, Decimal('0.1616')),
#  ('W10', 'L9533', 'R6', 'Chapel Hill', 'NC', 27517, 'apartment', '2', 'Y', 'N', 1200, 111, 149, 133, Decimal('0.3479')),
#  ('W100', 'L1944', 'R2', 'San Francisco', 'CA', 94129, 'apartment', '1', 'Y', 'N', 3300, 108, 610, 372, Decimal('0.3973')),
#  ('W101', 'L15257', 'R2', 'Austin', 'TX', 78702, 'apartment', '1', 'Y', 'N', 1400, 178, 533, 302, Decimal('0.3644')),
#  ('W102', 'L15257', 'R6', 'Austin', 'TX', 78702, 'apartment', '2', 'Y', 'N', 2000, 221, 617, 429, Decimal('0.4110')),
#  ('W103', 'L15257', 'R10', 'Austin', 'TX', 78702, 'house', '1', 'Y', 'N', 1600, 202, 646, 380, Decimal('0.4110')),
#  ('W104', 'L15257', 'R14', 'Austin', 'TX', 78702, 'house', '2', 'Y', 'N', 2800, 197, 639, 374, Decimal('0.5260')),
#  ('W105', 'L15260', 'R2', 'Austin', 'TX', 78705, 'apartment', '1', 'Y', 'N', 1100, 114, 477, 386, Decimal('0.4329')),
#  ('W106', 'L15260', 'R6', 'Austin', 'TX', 78705, 'apartment', '2', 'Y', 'N', 1900, 80, 583, 212, Decimal('0.6959')),
#  ('W107', 'L15260', 'R10', 'Austin', 'TX', 78705, 'house', '1', 'Y', 'N', 1800, 239, 1431, 969, Decimal('0.1096'))]

# %% [markdown]
# ### Finally, export the final query above as a .csv file for further examination in Excel and Tableau

# %%
Watershed_Properties_Data= %%sql \
SELECT w.ws_property_id, w.location, w.property_type, l.city, l.state, l.zipcode, p.apt_house, p.num_bedrooms, p.kitchen, \
p.shared, w.current_monthly_rent, sample_price.percentile_10th_price, sample_price.percentile_90th_price, \
sample_price.sample_nightly_rent_price, sample_dates.Occupancy \
FROM watershed_property_info w, location l, property_type p, \
    (SELECT w.ws_property_id, w.location, w.property_type, \
     sp.percentile_10th_price, sp.percentile_90th_price, \
     sp.sample_nightly_rent_price \
     FROM watershed_property_info w JOIN st_rental_prices sp \
       ON w.location=sp.location AND w.property_type=sp.property_type \
     GROUP BY w.ws_property_id) AS sample_price, \
    (SELECT w.ws_property_id, w.location, w.property_type, Sample.Occupancy \
     FROM watershed_property_info w LEFT JOIN (SELECT si.location, si.property_type, sd.st_property, COUNT(sd.rental_date)/365 \
                                               AS Occupancy \
                                               FROM st_property_info si JOIN st_rental_dates sd \
                                                 ON si.st_property_id=sd.st_property \
                                               WHERE EXTRACT(year FROM rental_date)=2015 \
                                               GROUP BY st_property) AS Sample \
       ON w.location=Sample.location AND w.property_type=Sample.property_type \
     GROUP BY w.ws_property_id) AS sample_dates \
WHERE w.property_type=p.property_type_id AND w.location=l.location_id AND w.ws_property_id=sample_price.ws_property_id AND \
w.ws_property_id=sample_dates.ws_property_id \
GROUP BY w.ws_property_id;

Watershed_Properties_Data.csv('Watershed Properties Data.csv')
# Out:
# 244 rows affected.
# CSV results at /home/jovyan/work/Capstone_course_materials/Watershed Properties Data.csv
